# %% [markdown]
# # Load data

# %%
#pip install biomart

# %%
#pip install gseapy

# %%
import pandas as pd
import scanpy as sc
import numpy as np

# %%
import gseapy as gp

# %% [markdown]
# # Read data

# %%
import scanpy as sc

# %%
adata = sc.read("/storage/users/sac43cg/res_Samantha_1/outs/per_sample_outs/time_adata.h5ad")
#adata = sc.read("../../data/time_adata.h5ad")

#adata = sc.read("/storage/users/sac43cg/res_Samantha_1/outs/per_sample_outs/time_adata.h5ad")
#adata = sc.read("/storage/users/sac43cg/res_Samantha_1/outs/per_sample_outs/annotated_adata.h5ad")

# %%
## make trivial names unique
#adata.var_names = adata.var_names.astype(str)
#adata.var_names_make_unique()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 10594 × 580
#     obs: 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'pct_cmo', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'leiden', 'leiden_combined', 'louvain', 'louvain_combined', 'index', 'IDs', 't', 'seg', 'edge', 't_sd', 'milestones', '43->30_lindev_sel', '43->94_lindev_sel'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'CMO', 'gene_symbol', 'mito', 'ribo', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', '43->30_rss', 'p_val', 'A', 'fdr', 'st', 'signi'
#     uns: '43->30_lindev_sel_colors', 'condition_colors', 'dendro_segments', 'draw_graph', 'graph', 'hvg', 'leiden', 'leiden_colors', 'leiden_combined_colors', 'log1p', 'louvain', 'louvain_combined_colors', 'milestones_colors', 'neighbors', 'pca', 'ppt', 'pseudotime_list', 'seg_colors', 'stat_assoc_list', 'umap'
#     obsm: 'X_R', 'X_dendro', 'X_draw_graph_fa', 'X_palantir', 'X_pca', 'X_pca2d', 'X_umap'
#     varm: 'PCs'
#     layers: 'fitted'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs.head()
# Out:
#                    condition  n_genes_by_counts  log1p_n_genes_by_counts  \
# barcode
# AAACCCAGTAGGCTCC-1    CTRL_1               3076                 8.031710
# AAACCCAGTCGCAACC-1    CTRL_1               4271                 8.359837
# AAACCCATCCACAAGT-1    CTRL_1               3517                 8.165648
# AAACGCTTCACTACGA-1    CTRL_1               4077                 8.313362
# AAACGCTTCAGCCTCT-1    CTRL_1               6263                 8.742574
#
#                     total_counts  log1p_total_counts  \
# barcode
# AAACCCAGTAGGCTCC-1         15109            9.623112
# AAACCCAGTCGCAACC-1         18912            9.847605
# AAACCCATCCACAAGT-1         14791            9.601842
# AAACGCTTCACTACGA-1         18788            9.841027
# AAACGCTTCAGCCTCT-1         32489           10.388688
#
#                     pct_counts_in_top_50_genes  pct_counts_in_top_100_genes  \
# barcode
# AAACCCAGTAGGCTCC-1                   54.359972                    65.514317
# AAACCCAGTCGCAACC-1                   58.422557                    66.296003
# AAACCCATCCACAAGT-1                   48.576595                    57.179024
# AAACGCTTCACTACGA-1                   50.601623                    60.215361
# AAACGCTTCAGCCTCT-1                   47.930883                    56.820337
#
#                     pct_counts_in_top_200_genes  pct_counts_in_top_500_genes  \
# barcode
# AAACCCAGTAGGCTCC-1                    73.540856                    81.846752
# AAACCCAGTCGCAACC-1                    72.210555                    78.996110
# AAACCCATCCACAAGT-1                    65.667786                    75.871868
# AAACGCTTCACTACGA-1                    68.136395                    76.612147
# AAACGCTTCAGCCTCT-1                    63.782934                    71.878976
#
#                       pct_cmo  ...  louvain_combined     index  \
# barcode                        ...
# AAACCCAGTAGGCTCC-1  24.628355  ...                 2  59054254
# AAACCCAGTCGCAACC-1  34.891727  ...                 2  -4772023
# AAACCCATCCACAAGT-1  23.580470  ...                 5  40775407
# AAACGCTTCACTACGA-1  23.367459  ...                 5  87425770
# AAACGCTTCAGCCTCT-1  24.847910  ...                 6  60538692
#
#                                 IDs         t  seg    edge      t_sd  \
# barcode
# AAACCCAGTAGGCTCC-1  CTRL_1_59054254  0.006717    6   67|13  0.012000
# AAACCCAGTCGCAACC-1  CTRL_1_-4772023  0.352433    6  147|12  0.049584
# AAACCCATCCACAAGT-1  CTRL_1_40775407  0.094585    6  31|131  0.048663
# AAACGCTTCACTACGA-1  CTRL_1_87425770  0.016908    6    1|13  0.020558
# AAACGCTTCAGCCTCT-1  CTRL_1_60538692  2.085327    9  172|32  0.034600
#
#                    milestones     43->30_lindev_sel 43->94_lindev_sel
# barcode
# AAACCCAGTAGGCTCC-1         43  putative progenitors   putative bridge
# AAACCCAGTCGCAACC-1         43       putative bridge   putative bridge
# AAACCCATCCACAAGT-1         43       putative bridge   putative bridge
# AAACGCTTCACTACGA-1         43       putative bridge   putative bridge
# AAACGCTTCAGCCTCT-1        162                   NaN               NaN
#
# [5 rows x 29 columns]

# %%
adata.var_names
# Out:
# Index(['HES4', 'ISG15', 'C1QTNF12', 'MFAP2', 'PADI2', 'CAMK2N1', 'HSPG2',
#        'ID3', 'SFN', 'SESN2',
#        ...
#        'SHROOM4', 'OPHN1', 'FTX', 'KLHL4', 'BEX2', 'DANT2', 'KLHL13', 'ZNF185',
#        'L1CAM', 'MT-CO2'],
#       dtype='object', length=580)

# %% [markdown]
# # Create dictionary

# %%
from biomart import BiomartServer

# Connect to the BioMart server
server = BiomartServer("http://ensembl.org/biomart")

# Select the human genes dataset
dataset = server.datasets['hsapiens_gene_ensembl']

# Query BioMart to get the translation from Ensembl ID to gene symbol
response = dataset.search({
    'attributes': ['ensembl_gene_id', 'external_gene_name'],
})

# Initialize an empty dictionary to store the mapping
ensembl_to_gene_name = {}

# Iterate through the response lines
for line in response.iter_lines():
    # Decode the line and split it into Ensembl ID and gene name
    decoded_line = line.decode('utf-8')
    ensembl_id, gene_name = decoded_line.split('\t')
    
    # Store the mapping in the dictionary
    ensembl_to_gene_name[ensembl_id] = gene_name

# Now, ensembl_to_gene_name is a dictionary with Ensembl IDs as keys and gene names as values.

# %% [markdown]
# # Individually define comparison : Define the Comparison and perform the GSEA analysis

# %% [markdown]
# ## Compare the conditons (testing)

# %%
# Create a new column 'cluster_category' based on the 'leiden' clusters
# Category 1: Clusters 3 and 15
# Category 2: Cluster 6
category_mapping = {'3': 'Category1', '15': 'Category1', '2': 'Category2', '7': 'Category2', '14': 'Category2'}
adata.obs['cluster_category'] = adata.obs['leiden'].map(category_mapping)

# Filter adata to include only the rows with the specified clusters (3, 15, 6)
adata = adata[adata.obs['cluster_category'].notnull()].copy()

# Optionally, you can check the first few rows to confirm
#print(adata.obs.head())
adata.obs.cluster_category
# Out:
# barcode
# AAGCGTTAGCCTCGTG-1    Category1
# ATCGGATGTTGAGGAC-1    Category2
# CATGGATGTGTATCCA-1    Category2
# CCACGAGTCCCATAAG-1    Category2
# CCGAACGAGAAACACT-1    Category2
#                         ...
# TTTACTGTCATTACTC-1    Category2
# TTTCACAGTGATATAG-1    Category1
# TTTCACATCGATGCAT-1    Category1
# TTTCATGTCCCTCTAG-1    Category2
# TTTGACTGTTCCGGTG-1    Category1
# Name: cluster_category, Length: 2896, dtype: object

# %%
# filter the adata bject for condition that are intended to compare
bdata = adata[adata.obs.cluster_category.isin(["Category1", "Category2"])].copy()

# %%
expression_df = bdata.to_df().T
#expression_df

# %%
expression_df
# Out:
# barcode          AAGCGTTAGCCTCGTG-1  ATCGGATGTTGAGGAC-1  CATGGATGTGTATCCA-1  \
# feature_id
# ENSG00000188290            1.982747            2.213767            0.778701
# ENSG00000187608            0.760183            1.773268            0.000000
# ENSG00000224969            0.000000            0.000000            0.000000
# ENSG00000184163            0.000000            0.000000            0.000000
# ENSG00000049249            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# ENSG00000198883            0.000000            0.000000            0.000000
# ENSG00000182492            0.000000            0.000000            0.000000
# ENSG00000067842            0.000000            0.000000            0.000000
# ENSG00000198910            0.760183            0.000000            0.000000
# ENSG00000198712            5.241112            3.770013            5.844017
#
# barcode          CCACGAGTCCCATAAG-1  CCGAACGAGAAACACT-1  CCGGACAGTCGACGCT-1  \
# feature_id
# ENSG00000188290            1.961813            1.183782            1.786503
# ENSG00000187608            0.798606            0.000000            0.603272
# ENSG00000224969            0.000000            0.000000            0.000000
# ENSG00000184163            0.000000            0.000000            1.461486
# ENSG00000049249            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# ENSG00000198883            0.000000            0.000000            0.000000
# ENSG00000182492            0.000000            0.000000            0.000000
# ENSG00000067842            0.000000            0.000000            0.000000
# ENSG00000198910            0.000000            0.920735            0.603272
# ENSG00000198712            4.129101            3.943969            4.566745
#
# barcode          CGAGGCTAGAACTGAT-1  CGCCAGATCTAGAACC-1  CGCCATTAGAACGTGC-1  \
# feature_id
# ENSG00000188290            0.560981            1.390868            2.051576
# ENSG00000187608            0.918202            0.000000            0.000000
# ENSG00000224969            0.000000            0.000000            0.000000
# ENSG00000184163            0.000000            0.000000            0.000000
# ENSG00000049249            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# ENSG00000198883            0.000000            0.000000            0.000000
# ENSG00000182492            0.000000            0.000000            0.000000
# ENSG00000067842            0.000000            0.000000            0.000000
# ENSG00000198910            0.918202            0.696199            0.856978
# ENSG00000198712            4.546444            4.549324            3.235086
#
# barcode          CGGAATTAGAGCAAGA-1  ...  TTGTGGATCTAGCAAC-1  \
# feature_id                           ...
# ENSG00000188290            1.494525  ...            1.621794
# ENSG00000187608            0.622888  ...            0.000000
# ENSG00000224969            0.000000  ...            0.000000
# ENSG00000184163            0.000000  ...            0.000000
# ENSG00000049249            0.000000  ...            0.000000
# ...                             ...  ...                 ...
# ENSG00000198883            0.000000  ...            0.000000
# ENSG00000182492            1.003792  ...            0.000000
# ENSG00000067842            0.000000  ...            0.000000
# ENSG00000198910            0.622888  ...            0.000000
# ENSG00000198712            4.440739  ...            4.576131
#
# barcode          TTGTTCACAGGTCAAG-1  TTGTTTGAGCTCATAC-1  TTTACGTTCAAGGCTT-1  \
# feature_id
# ENSG00000188290            2.052788            2.241301            0.000000
# ENSG00000187608            0.000000            1.335489            0.000000
# ENSG00000224969            0.000000            0.000000            0.000000
# ENSG00000184163            0.000000            0.000000            0.000000
# ENSG00000049249            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# ENSG00000198883            0.000000            0.000000            0.000000
# ENSG00000182492            0.000000            0.000000            0.000000
# ENSG00000067842            0.000000            0.000000            0.000000
# ENSG00000198910            1.480421            1.335489            0.000000
# ENSG00000198712            5.530282            4.043701            4.378127
#
# barcode          TTTACTGCAGCTACAT-1  TTTACTGTCATTACTC-1  TTTCACAGTGATATAG-1  \
# feature_id
# ENSG00000188290            1.883256            2.679670            1.877891
# ENSG00000187608            1.050225            1.127936            0.802469
# ENSG00000224969            0.000000            0.000000            0.000000
# ENSG00000184163            0.000000            0.000000            0.000000
# ENSG00000049249            0.000000            0.000000            0.479658
# ...                             ...                 ...                 ...
# ENSG00000198883            0.000000            0.000000            0.000000
# ENSG00000182492            0.000000            0.000000            1.046113
# ENSG00000067842            0.000000            0.000000            0.000000
# ENSG00000198910            0.657078            0.715220            0.479658
# ENSG00000198712            3.898241            4.770679            4.738441
#
# barcode          TTTCACATCGATGCAT-1  TTTCATGTCCCTCTAG-1  TTTGACTGTTCCGGTG-1
# feature_id
# ENSG00000188290            1.520372            1.049049            0.763774
# ENSG00000187608            0.000000            0.000000            0.763774
# ENSG00000224969            0.000000            0.000000            0.000000
# ENSG00000184163            0.000000            0.000000            0.000000
# ENSG00000049249            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# ENSG00000198883            0.000000            0.000000            0.000000
# ENSG00000182492            0.000000            0.000000            0.000000
# ENSG00000067842            0.000000            0.000000            0.000000
# ENSG00000198910            2.097755            0.000000            0.000000
# ENSG00000198712            3.781621            4.634937            4.065913
#
# [2000 rows x 2896 columns]

# %%
## perfrom GSEA anaylsis for the selected comparisons

res = gp.gsea(data=expression_df,
    gene_sets="Reactome_2022",
    cls=bdata.obs.cluster_category,
    permutation_num=1000,
   # permutation_type='phenotype',
    outdir=None,
    method='s2n', # signal_to_noise
    threads= 16)

# %%
# print head results
res.res2d.head()
print(res.res2d.head())

# Visualize the top pathways
terms = res.res2d.Term
axs = res.plot(terms[:10], show_ranking=False, legend_kws={'loc': (1.05, 0)}, )

# %% [markdown]
# ## Compare the Clusters (milestones, leiden)

# %% [markdown]
# #### Define the comparisons

# %%
group1 = '1resistant_time_all'
group2 = '2non-reistant_time_all'

comparison = group1 + "_vs_" + group2

group1_cluster = ["3","15","6","17","9","4"]
#group1_cluster = ["6","17"]
#group1_cluster = ["3","15"]
#group1_cluster = ["9","4"]
group2_cluster = ["2","7","14","5","11","8","10","12","13","0"]
#group2_cluster = ["1","5","11","8"]
#group2_cluster = ["2","7","14"]
#group2_cluster = ["10","12","13","0"]

# %%
def label_clusters(cluster):
    if cluster in group1_cluster:
        return group1
    elif cluster in group2_cluster:
        return group2
    else:
        return "NA"  # This label will be used to filter out other clusters


# Create a new categorical column for comparison
adata.obs['compare_clusters'] = adata.obs['leiden'].map(label_clusters)

# Subset the data for only the two groups you're comparing
bdata = adata[adata.obs.compare_clusters.isin([group1, group2])].copy()

# sort indices to define the direction of comparison (could for interpretation of the results :)
sorted_indices = bdata.obs.sort_values(by='compare_clusters').index
bdata = bdata[sorted_indices]

# create a dataframe from bdata and translae ensembl ID to symbol (if not done before!!)
expression_df = bdata.to_df().T

# %%
expression_df
# Out:
# barcode   GGACGTCGTGGAACAC-1  GTAACCAAGCTGTTCA-1  GTAACACTCGTGGTAT-1  \
# HES4                0.000000            1.024112            1.295231
# ISG15               1.451715            0.466794            0.844116
# C1QTNF12            0.000000            0.000000            0.000000
# MFAP2               0.597522            0.000000            0.000000
# PADI2               0.597522            0.783786            0.366013
# ...                      ...                 ...                 ...
# DANT2               1.239193            0.466794            0.000000
# KLHL13              0.000000            1.641734            0.000000
# ZNF185              0.000000            0.000000            0.000000
# L1CAM               0.597522            0.000000            0.000000
# MT-CO2              4.628725            5.062890            4.914446
#
# barcode   GGTTGTATCTAGCAAC-1  GGTTGTAAGTGGTTCT-1  GGTTAACAGTATCTGC-1  \
# HES4                0.386826            1.292752            1.420309
# ISG15               0.386826            0.507239            0.852298
# C1QTNF12            0.000000            0.507239            0.370420
# MFAP2               0.000000            0.000000            0.000000
# PADI2               0.665057            1.292752            0.640108
# ...                      ...                 ...                 ...
# DANT2               0.386826            1.459428            0.640108
# KLHL13              0.882487            0.000000            0.852298
# ZNF185              0.386826            0.000000            0.640108
# L1CAM               0.000000            0.000000            0.000000
# MT-CO2              5.440417            5.407150            5.138580
#
# barcode   GGTGTTATCCCTCGTA-1  GGTGTTAGTTCAGCTA-1  GGTGTCGTCGTGCATA-1  \
# HES4                1.306413            0.506674            0.966510
# ISG15               0.000000            0.506674            0.735170
# C1QTNF12            0.000000            0.000000            0.000000
# MFAP2               0.000000            0.506674            0.000000
# PADI2               1.306413            0.000000            0.000000
# ...                      ...                 ...                 ...
# DANT2               0.370748            0.841361            0.000000
# KLHL13              0.000000            0.506674            0.735170
# ZNF185              0.000000            0.000000            0.000000
# L1CAM               0.000000            0.506674            0.000000
# MT-CO2              5.265498            5.276223            5.360061
#
# barcode   GGTGTCGGTCGAGATG-1  ...  TCCGAAATCTGCATAG-1  GTCCCATAGCTCAGAG-1  \
# HES4                0.000000  ...            0.819760            2.148976
# ISG15               1.056082  ...            0.000000            1.062646
# C1QTNF12            0.000000  ...            0.000000            0.000000
# MFAP2               0.000000  ...            0.000000            0.000000
# PADI2               0.661420  ...            0.000000            0.000000
# ...                      ...  ...                 ...                 ...
# DANT2               0.661420  ...            0.000000            1.566121
# KLHL13              1.056082  ...            0.000000            0.000000
# ZNF185              0.000000  ...            0.000000            0.000000
# L1CAM               0.661420  ...            0.000000            0.000000
# MT-CO2              5.899257  ...            4.484435            5.591198
#
# barcode   TCCGATCAGCACTAAA-1  GTCCACTAGGACAGTC-1  TCCGATCCATTGCTGA-1  \
# HES4                0.000000            1.629920            0.897399
# ISG15               0.753745            0.521119            0.000000
# C1QTNF12            0.000000            0.000000            0.000000
# MFAP2               0.000000            0.521119            0.000000
# PADI2               0.000000            1.317920            0.000000
# ...                      ...                 ...                 ...
# DANT2               1.178620            1.755679            0.897399
# KLHL13              0.000000            1.115709            0.897399
# ZNF185              0.753745            0.000000            0.897399
# L1CAM               0.000000            0.000000            0.897399
# MT-CO2              4.953132            5.256511            5.559420
#
# barcode   GTCATTTGTCAGACTT-1  GTCATGATCATTTGTC-1  GTCATGACAACACAAA-1  \
# HES4                0.836086            1.382061            1.879269
# ISG15               1.284992            1.052372            1.328230
# C1QTNF12            0.000000            0.000000            0.000000
# MFAP2               0.000000            0.000000            0.000000
# PADI2               1.593706            0.750785            0.654815
# ...                      ...                 ...                 ...
# DANT2               0.502991            1.553688            1.328230
# KLHL13              0.836086            0.912905            0.000000
# ZNF185              0.000000            0.316916            0.000000
# L1CAM               0.000000            0.000000            0.654815
# MT-CO2              5.028141            5.282015            5.215520
#
# barcode   GTCCTCACATTGACCA-1  AAACCCAGTCGCAACC-1
# HES4                1.487496            1.817618
# ISG15               0.000000            0.000000
# C1QTNF12            0.000000            2.106576
# MFAP2               0.000000            0.000000
# PADI2               2.258111            0.000000
# ...                      ...                 ...
# DANT2               1.189062            1.634275
# KLHL13              0.451712            0.000000
# ZNF185              0.000000            0.000000
# L1CAM               0.451712            0.000000
# MT-CO2              4.771151            3.207734
#
# [580 rows x 9435 columns]

# %% [markdown]
# ### If neccessary translate ID's to gene symbols

# %%
# Gen-IDs aus der Datei extrahieren
deg_gene_ids = expression_df.iloc[:, 0]
deg_gene_ids
# Out:
# HES4        0.000000
# ISG15       1.451715
# C1QTNF12    0.000000
# MFAP2       0.597522
# PADI2       0.597522
#               ...
# DANT2       1.239193
# KLHL13      0.000000
# ZNF185      0.000000
# L1CAM       0.597522
# MT-CO2      4.628725
# Name: GGACGTCGTGGAACAC-1, Length: 580, dtype: float32

# %%
# translate ensembl_to_gene_name
mapping_dict = ensembl_to_gene_name

# Assuming expression_df is your DataFrame with Ensembl IDs (feature_id) as the index
# Map the Ensembl IDs in the index to gene symbols
new_index = expression_df.index.map(lambda x: mapping_dict.get(x, x))
new_index
# Out:
# Index(['HES4', 'ISG15', 'C1QTNF12', 'MFAP2', 'PADI2', 'CAMK2N1', 'HSPG2',
#        'ID3', 'SFN', 'SESN2',
#        ...
#        'SHROOM4', 'OPHN1', 'FTX', 'KLHL4', 'BEX2', 'DANT2', 'KLHL13', 'ZNF185',
#        'L1CAM', 'MT-CO2'],
#       dtype='object', length=580)

# %%
# Replace the index of the original DataFrame
expression_df.index = new_index

# Rename the index name to 'gene_name'
expression_df.index.name = 'gene_name'

# %%
#expression_df.head()

# %% [markdown]
# ### Perform GSEA and visualize

# %%
#help(gp.gsea)

# %%
## Get the names for the pathway libraries and select one in the gsea function
names = gp.get_library_name()
#print(names)

# %%
bdata.obs.compare_clusters
# Out:
# barcode
# GGACGTCGTGGAACAC-1       1resistant_time_all
# GTAACCAAGCTGTTCA-1       1resistant_time_all
# GTAACACTCGTGGTAT-1       1resistant_time_all
# GGTTGTATCTAGCAAC-1       1resistant_time_all
# GGTTGTAAGTGGTTCT-1       1resistant_time_all
#                                ...
# GTCATTTGTCAGACTT-1    2non-reistant_time_all
# GTCATGATCATTTGTC-1    2non-reistant_time_all
# GTCATGACAACACAAA-1    2non-reistant_time_all
# GTCCTCACATTGACCA-1    2non-reistant_time_all
# AAACCCAGTCGCAACC-1    2non-reistant_time_all
# Name: compare_clusters, Length: 9435, dtype: object

# %%
# Example of how to create a binary class list for GSEA
# Let's say you want to compare 'group1' vs 'group2' in 'compare_clusters'
binary_cls = ['group1' if cluster == 'non-resistant' else 'group2' for cluster in bdata.obs.compare_clusters]
binary_cls[0:10]
# Out:
# ['group2',
#  'group2',
#  'group2',
#  'group2',
#  'group2',
#  'group2',
#  'group2',
#  'group2',
#  'group2',
#  'group2']

# %%
# Now you can run GSEA on this filtered data, using the cluster2 label:
# When you are running GSEA, make sure to use the new cluster2 la
res = gp.gsea(data=expression_df,
              #gene_sets="GO_Biological_Process_2023",
              #gene_sets="Reactome_2022",
              gene_sets="MSigDB_Hallmark_2020",
              cls=bdata.obs.compare_clusters, 
              #cls=binary_cls,
              permutation_num=1000,
              outdir=None,
              min_size= 10, 
              max_size = 50,
              method='log2_ratio_of_classes', 
              threads=26)

# %%
# print head results
print(res.res2d.head(15))
# Out:
#     Name                    Term        ES       NES NOM p-val FDR q-val  \
# 0   gsea         Mitotic Spindle  0.864613  2.377526       0.0       0.0
# 1   gsea              Glycolysis  0.667324  2.074404       0.0   0.00126
# 2   gsea         G2-M Checkpoint  0.910921  2.030818       0.0   0.00126
# 3   gsea             E2F Targets  0.897673  1.914524       0.0  0.004409
# 4   gsea               Apoptosis  0.490345  1.597971   0.01919  0.073317
# 5   gsea        mTORC1 Signaling  0.620571  1.581449  0.017316  0.069496
# 6   gsea              Complement -0.530988  -1.35481  0.119318       1.0
# 7   gsea       Androgen Response -0.545223 -1.235465  0.228797       1.0
# 8   gsea       KRAS Signaling Up  0.506465  1.216265  0.213592  0.555727
# 9   gsea  Estrogen Response Late  0.526172  1.145557  0.307385  0.631761
# 10  gsea   Xenobiotic Metabolism  0.661522  1.127824  0.349794  0.593899
# 11  gsea             p53 Pathway  0.357286  1.022974  0.437367  0.721455
# 12  gsea      TGF-beta Signaling -0.397139 -1.003305  0.467327       1.0
# 13  gsea              Myogenesis  0.353479  0.928428  0.539526  0.815054
# 14  gsea                 Hypoxia -0.349115 -0.915313  0.560748       1.0
#
#    FWER p-val  Tag %  Gene %  \
# 0         0.0  15/29   7.41%
# 1       0.002   5/25   4.31%
# 2       0.003  21/27   9.48%
# 3       0.012  21/24   9.48%
# 4       0.209   8/23  28.28%
# 5       0.226   7/21  18.45%
# 6       0.682   7/15  29.66%
# 7       0.831  10/16  35.52%
# 8       0.843   7/19  21.38%
# 9       0.893   6/11  25.86%
# 10      0.902   7/11  28.28%
# 11      0.944  16/29  31.90%
# 12      0.955   8/16  38.45%
# 13       0.97   5/17  25.86%
# 14      0.977  27/47  41.90%
#
#                                            Lead_genes
# 0   CDK1;KIF2C;TOP2A;CENPE;NUSAP1;ANLN;BUB1;AURKA;...
# 1                        CDK1;HMMR;CENPA;DEPDC1;AURKA
# 2   CDK1;KIF2C;TOP2A;KNL1;MKI67;CENPE;NUSAP1;HMMR;...
# 3   CDK1;KIF2C;TOP2A;DIAPH3;CDCA8;MKI67;CENPE;HMMR...
# 4   TOP2A;HMGB2;CDKN1A;BIRC3;DDIT3;GADD45A;GADD45B...
# 5            BUB1;RRM2;AURKA;TUBA4A;CDKN1A;DDIT3;GOT1
# 6                 CD55;CBLB;DOCK4;CP;PDGFB;LGALS3;FN1
# 7   TSC22D1;ELL2;NDRG1;KRT19;H1-0;KRT8;SAT1;SGK1;A...
# 8              PLAU;ETV4;G0S2;BIRC3;TMEM158;DUSP6;ID2
# 9                      TOP2A;CDC20;SFN;IGFBP4;ID2;CKB
# 10           IGFBP1;IGFBP4;ID2;UPP1;TPST1;PPARD;HMOX1
# 11  CD82;CDKN1A;SDC1;H1-2;SFN;DDIT3;UPP1;RNF19B;GA...
# 12         NOG;JUNB;THBS1;BCAR3;BMPR2;ID3;SKIL;SMURF2
# 13                        CDKN1A;SLN;NAV2;GADD45B;CKB
# 14  SLC2A3;FOS;CITED2;CP;ANGPTL4;CCN2;NDRG1;EXT1;C...

# %%
# !pwd
# Out:
# /home2/lumpi/Projects/single-cell_samantha/code/scripts

# %%
path = "/home2/lumpi/Projects/single-cell_samantha/data/res_gsea_hallmark" + comparison + ".csv"
path
# Out:
# '/home2/lumpi/Projects/single-cell_samantha/data/res_gsea_hallmark1resistant_time_all_vs_2non-reistant_time_all.csv'

# %%
# write to file location
res.res2d.to_csv(path, index=False)

# %%
import matplotlib.pyplot as plt
# Visualize the top pathways
terms = res.res2d.Term
print(terms)
axs = res.plot(terms[:10], show_ranking=False, legend_kws={'loc': (1.05, 0)}, )

# Assuming axs is a matplotlib Axes object, you save the figure like this:
plt.savefig("gsea_plot_hallmark" + comparison + ".png", bbox_inches='tight')
# Out:
# 0                       Mitotic Spindle
# 1                            Glycolysis
# 2                       G2-M Checkpoint
# 3                           E2F Targets
# 4                             Apoptosis
# 5                      mTORC1 Signaling
# 6                            Complement
# 7                     Androgen Response
# 8                     KRAS Signaling Up
# 9                Estrogen Response Late
# 10                Xenobiotic Metabolism
# 11                          p53 Pathway
# 12                   TGF-beta Signaling
# 13                           Myogenesis
# 14                              Hypoxia
# 15                Inflammatory Response
# 16            Interferon Gamma Response
# 17                      Apical Junction
# 18                       UV Response Dn
# 19                       UV Response Up
# 20                      heme Metabolism
# 21        TNF-alpha Signaling via NF-kB
# 22              Estrogen Response Early
# 23                 IL-2/STAT5 Signaling
# 24                          Coagulation
# 25    Epithelial Mesenchymal Transition
# Name: Term, dtype: object

# %% [markdown]
# ### Get the genes in the pathway

# %%
data = res.res2d
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Extracting lead_genes
lead_genes = data['Lead_genes'].head(15)

# Printing the lead_genes
for i, genes in enumerate(lead_genes, 1):
    print(f"Row {i} Lead Genes: {genes}")
# Out:
# Row 1 Lead Genes: H1-5;DEPDC1;CENPF;HMGB2;BIRC5;E2F7;BMP6;DDIT3;EDN1;ID2;PPARD;LOXL2;GADD45A;NR6A1
# Row 2 Lead Genes: DEPDC1;CENPF;HMGB2;BIRC5;ATAD2;ERBB4;FOSL1;ETV4;E2F7;PBX3;DDIT3;ID2;RYBP;PPARD;LOXL2;NR6A1;HES4;BTG1
# Row 3 Lead Genes: KIF14;KIF20B;HMGB2;BIRC5;PRC1;CDKN3;ERBB4;FOSL1;E2F7;CDKN1A;BMP6;CADM4
# Row 4 Lead Genes: CKAP2;HMGB2;ATAD2;ERBB4;FOSL1;ETV4;E2F7;H2AZ1;BMP6;WWOX;DDIT3;EDN1;ID2;RYBP;PPARD;AUTS2
# Row 5 Lead Genes: PRKN;NOG;ZBTB20;CITED2;PTHLH;GJA1;BACH1;CUX2;AGR2;ZNF804A;NFATC2;EGR1;AFF3;ADAM19;RBMS3;VEGFA;SUPT3H;ATP1B1;PDGFB;FN1;NFKBIZ;ZFP36L1;BMPR2;MEF2C;GPI;ZNF407
# Row 6 Lead Genes: H1-5;CKAP2;HMGB2;ATAD2;FOSL1;ETV4;E2F7;H2AZ1;BMP6;WWOX;PBX3;DDIT3;EDN1;ID2;PPARD;LOXL2;GADD45A;AUTS2;NR6A1;HES4;ID1;CRY1;MELTF;ETS1;HES1;FGF1;NFKBIA;IRF1;DKK1

# %% [markdown]
# ### Visualize the Pathway and the logFCs of the genes in R

# %% [raw]
# # execute R script 11_Pathway_anaylsis or similar

# %% [markdown]
# ### Some barcode annotation: Forgot why :)

# %%
# Translate Barcode to Conditons
barcode_to_condition = adata.obs['condition'].to_dict()
#barcode_to_condition

# Extract barcodes from GSEA results
#barcodes = res.res2d.index.tolist()
barcodes = res.res2d.columns.tolist()
barcodes

# Print terms
#terms

# %%
#help(gp.gsea)

# %% [markdown]
# ## Print Heatmap

# %%
from gseapy import heatmap
# plotting heatmap
i = 2
genes = res.res2d.Lead_genes[i].split(";")
# Make sure that ``ofname`` is not None, if you want to save your figure to disk


df_heat = res.heatmat.loc[genes]
barcode_to_condition

new_columns = df_heat.columns.map(barcode_to_condition.get)

# Assign the new column names back to the DataFrame
df_heat.columns = new_columns


ax = heatmap(df = df_heat, z_score=0, title=terms[i], figsize=(14,4))

gs_res = res
gs_res.heatmat.loc[genes]

# %% [markdown]
# ## Plot Bubbleplot

# %%
import matplotlib.pyplot as plt

from gseapy import dotplot
# to save your figure, make sure that ``ofname`` is not None
ax = dotplot(gs_res.res2d,
column="FDR q-val",
title='KEGG_2021_Human',
cmap=plt.cm.viridis,
size=5,
figsize=(4,5), cutoff=1)

# %% [markdown]
# ## Plot pathway network

# %%
import networkx as nx

# %%
res.res2d.head()
# Out:
#    Name                                               Term        ES  \
# 0  gsea    Extracellular Matrix Organization R-HSA-1474244 -0.607517
# 1  gsea     Signaling By TGFB Family Members R-HSA-9006936   -0.6769
# 2  gsea  Signaling By TGF-beta Receptor Complex R-HSA-1... -0.708324
# 3  gsea                   Collagen Formation R-HSA-1474290 -0.625634
# 4  gsea                Platelet Degranulation R-HSA-114608 -0.599753
#
#         NES NOM p-val FDR q-val FWER p-val  Tag %  Gene %  \
# 0 -2.183252  0.002257  0.005501      0.003  46/87  20.74%
# 1 -2.148591       0.0  0.005501      0.005  15/33   8.67%
# 2 -2.119574       0.0  0.006112      0.008  13/26   8.67%
# 3 -1.975415  0.002257  0.055464      0.059  22/35  25.57%
# 4 -1.969447       0.0  0.049505      0.065  15/32  16.13%
#
#                                           Lead_genes
# 0  SERPINE1;MMP2;COL1A1;COL5A1;PDGFA;LOX;ADAM19;P...
# 1  PMEPA1;SERPINE1;SKIL;ITGAV;BMPR2;SMURF2;ARHGEF...
# 2  PMEPA1;SERPINE1;SKIL;ITGAV;SMURF2;ARHGEF18;SMA...
# 3  COL1A1;COL5A1;LOX;COL22A1;PLOD2;COL7A1;P4HA3;C...
# 4  SERPINE1;PDGFA;PDGFB;TAGLN2;TUBA4A;IGF2;THBS1;...

# %%
 nodes, edges = gp.enrichment_map(res.res2d)

# %%
nodes.head()
# Out:
#           Name                                               Term        ES  \
# node_idx
# 0         gsea  Non-integrin membrane-ECM Interactions R-HSA-3... -0.632753
# 1         gsea                Platelet Degranulation R-HSA-114608 -0.599753
# 2         gsea  Collagen Biosynthesis And Modifying Enzymes R-...  -0.68322
# 3         gsea  TGF-beta Receptor Signaling Activates SMADs R-... -0.690859
# 4         gsea  Response To Elevated Platelet Cytosolic Ca2+ R... -0.586327
#
#                NES NOM p-val FDR q-val FWER p-val  Tag %  Gene %  \
# node_idx
# 0        -1.885516  0.006356  0.049963      0.137  10/22  11.40%
# 1        -1.969447       0.0  0.049505      0.065  15/32  16.13%
# 2        -1.935332  0.002227  0.046525      0.089  18/24  25.57%
# 3        -1.931101       0.0  0.042578      0.089  11/18  17.27%
# 4        -1.967738       0.0  0.041865      0.065  15/34  16.13%
#
#                                                  Lead_genes     p_inv  \
# node_idx
# 0         PDGFA;PDGFB;ITGAV;THBS1;SDC1;TGFB1;ITGB3;LAMB3...  1.301351
# 1         SERPINE1;PDGFA;PDGFB;TAGLN2;TUBA4A;IGF2;THBS1;...  1.305353
# 2         COL1A1;COL5A1;COL22A1;PLOD2;COL7A1;P4HA3;COL15...  1.332311
# 3         PMEPA1;ITGAV;SMURF2;SMAD7;TGFB1;LTBP3;TGFBR1;F...  1.370813
# 4         SERPINE1;PDGFA;PDGFB;TAGLN2;TUBA4A;IGF2;THBS1;...  1.378148
#
#           Hits_ratio
# node_idx
# 0           0.454545
# 1           0.468750
# 2           0.750000
# 3           0.611111
# 4           0.441176

# %%
edges.head()
# Out:
#    src_idx  targ_idx                                           src_name  \
# 0        0         1  Non-integrin membrane-ECM Interactions R-HSA-3...
# 1        0         3  Non-integrin membrane-ECM Interactions R-HSA-3...
# 2        0         4  Non-integrin membrane-ECM Interactions R-HSA-3...
# 3        0         5  Non-integrin membrane-ECM Interactions R-HSA-3...
# 4        0         6  Non-integrin membrane-ECM Interactions R-HSA-3...
#
#                                            targ_name  jaccard_coef  \
# 0                Platelet Degranulation R-HSA-114608      0.250000
# 1  TGF-beta Receptor Signaling Activates SMADs R-...      0.166667
# 2  Response To Elevated Platelet Cytosolic Ca2+ R...      0.250000
# 3  Signaling By TGF-beta Receptor Complex R-HSA-1...      0.150000
# 4    Extracellular Matrix Organization R-HSA-1474244      0.217391
#
#    overlap_coef                                      overlap_genes
# 0           0.5                      PDGFB,ITGB3,THBS1,PDGFA,TGFB1
# 1           0.3                                  ITGB3,ITGAV,TGFB1
# 2           0.5                      PDGFB,ITGB3,THBS1,PDGFA,TGFB1
# 3           0.3                                  ITGB3,ITGAV,TGFB1
# 4           1.0  PDGFB,ITGA2,ITGB3,THBS1,PDGFA,SDC2,LAMB3,ITGAV...

# %%
# build graph
G = nx.from_pandas_edgelist(edges,
    source='src_idx',
    target='targ_idx',
    edge_attr=['jaccard_coef', 'overlap_coef', 'overlap_genes'])

# %%
fig, ax = plt.subplots(figsize=(8, 8))
# init node cooridnates
pos=nx.layout.spiral_layout(G)
#node_size = nx.get_node_attributes()
# draw node
nx.draw_networkx_nodes(G,
pos=pos,
cmap=plt.cm.RdYlBu,
node_color=list(nodes.NES),
node_size=list(nodes.Hits_ratio *1000))
# draw node label
nx.draw_networkx_labels(G,
pos=pos,
labels=nodes.Term.to_dict())
# draw edge
edge_weight = nx.get_edge_attributes(G, 'jaccard_coef').values()
nx.draw_networkx_edges(G,
pos=pos,
width=list(map(lambda x: x*10, edge_weight)),
edge_color='#CDDBD4')
plt.show()

# %% [markdown]
# # PFA analysis

# %%
https://github.com/LauritzR/Principal-Feature-Analysis

# %%
https://github.com/AC-PHD/Seurat_PFA_pipeline

# %% [markdown]
# # Prepare environment

# %%
# !conda create -n PFA python=3.8 -y

# %%
# !conda activate PFA

# %%
# !conda install -n PFA csv random os ipython -y

# %%
# !conda install -n PFA ipykernel -y

# %%
# !python -m ipykernel install --user --name PFA --display-name "Python (PFA)"

# %%
# !conda install -c anaconda pandas

# %%
# !conda install -c bioconda scanpy

# %%
# !conda install -c anaconda requests

# %%
!

# %% [markdown]
# # Prepare the PFA input matrix

# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import os

# %% [markdown]
# ## Load and subset the adata object

# %%
adata = sc.read("/storage/users/sac43cg/res_Samantha_1/outs/per_sample_outs/time_adata.h5ad")
#adata = sc.read("/storage/users/sac43cg/res_Samantha_1/outs/per_sample_outs/time_adata.h5ad")

# %%
# Define the substrings you're interested in
substrings = ['CTRL', 'TGFB1', 'GEM']

# Filter gene names by checking if they contain any of the substrings
filtered_genes = [name for name in adata.var_names if any(substring in name for substring in substrings)]

# %%
# Filter the AnnData object to keep only the selected genes
adata_filtered = adata[:, filtered_genes]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 10594 × 580
#     obs: 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'pct_cmo', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'leiden', 'leiden_combined', 'louvain', 'louvain_combined', 'index', 'IDs', 't', 'seg', 'edge', 't_sd', 'milestones', '43->30_lindev_sel', '43->94_lindev_sel'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'CMO', 'gene_symbol', 'mito', 'ribo', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', '43->30_rss', 'p_val', 'A', 'fdr', 'st', 'signi'
#     uns: '43->30_lindev_sel_colors', 'condition_colors', 'dendro_segments', 'draw_graph', 'graph', 'hvg', 'leiden', 'leiden_colors', 'leiden_combined_colors', 'log1p', 'louvain', 'louvain_combined_colors', 'milestones_colors', 'neighbors', 'pca', 'ppt', 'pseudotime_list', 'seg_colors', 'stat_assoc_list', 'umap'
#     obsm: 'X_R', 'X_dendro', 'X_draw_graph_fa', 'X_palantir', 'X_pca', 'X_pca2d', 'X_umap'
#     varm: 'PCs'
#     layers: 'fitted'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ## Prepare the Group-Annotation of the Count Matrix

# %% [raw]
# # the PFA algorithm needs a certain format with a count matrix and the first row the label for the groups (here Leiden Clusters)
# # but all others groupings could be applied

# %%
# Assuming you have already loaded your Adata object
# Replace 'adata' with your Adata object's variable name
# and make sure to replace 'leiden' with the correct clustering key

# Create a DataFrame for the Leiden annotation
leiden_series = pd.Series(adata.obs['leiden'], name='Label')

# Extract the count matrix from adata
count_matrix = adata.X

count_matrix = count_matrix.T

# Convert the count matrix to a DataFrame with genes as rows and samples as columns
count_df = pd.DataFrame(count_matrix.toarray(), index=adata.var_names, columns=adata.obs_names)

# Add the Leiden annotation as the first row
count_df = pd.concat([leiden_series.to_frame().T, count_df], axis=0)

# %%
count_df = count_df[count_df.index.notnull() & (count_df.index != '')]

# %%
count_df
# Out:
# barcode  AAACCCAGTAGGCTCC-1 AAACCCAGTCGCAACC-1 AAACCCATCCACAAGT-1  \
# Label                     1                 11                  5
# HES4               1.583742           1.817618                0.0
# ISG15                   0.0                0.0                0.0
# C1QTNF12                0.0           2.106576                0.0
# MFAP2                   0.0                0.0                0.0
# ...                     ...                ...                ...
# DANT2                   0.0           1.634275                0.0
# KLHL13                  0.0                0.0                0.0
# ZNF185                  0.0                0.0           1.291329
# L1CAM                   0.0                0.0                0.0
# MT-CO2             3.963516           3.207734            4.12172
#
# barcode  AAACGCTTCACTACGA-1 AAACGCTTCAGCCTCT-1 AAAGAACAGATACAGT-1  \
# Label                     8                  6                  1
# HES4               1.823131           0.470256           1.036066
# ISG15                   0.0           0.470256                0.0
# C1QTNF12                0.0                0.0                0.0
# MFAP2                   0.0                0.0                0.0
# ...                     ...                ...                ...
# DANT2                   0.0           1.946486           0.646608
# KLHL13                  0.0           1.030051           1.036066
# ZNF185             0.712088                0.0           0.646608
# L1CAM              0.712088                0.0                0.0
# MT-CO2             4.241672           4.708393           4.065095
#
# barcode  AAAGAACAGCCTCGTG-1 AAAGAACAGTAATCCC-1 AAAGAACCAACATCGT-1  \
# Label                     6                  8                  6
# HES4                0.88049           1.708302           2.782923
# ISG15                   0.0           0.918898           0.866574
# C1QTNF12                0.0                0.0           0.524357
# MFAP2                   0.0                0.0                0.0
# ...                     ...                ...                ...
# DANT2                   0.0                0.0                0.0
# KLHL13                  0.0           1.949632                0.0
# ZNF185                  0.0                0.0                0.0
# L1CAM               0.88049                0.0                0.0
# MT-CO2             4.807613           3.530574           5.400871
#
# barcode  AAAGAACGTCGCGGTT-1  ... TTGTGGATCTAGCAAC-1 TTGTTCACAGGTCAAG-1  \
# Label                     1  ...                  3                  3
# HES4                1.21865  ...           1.621794           2.052788
# ISG15                   0.0  ...                0.0                0.0
# C1QTNF12                0.0  ...                0.0                0.0
# MFAP2                   0.0  ...                0.0                0.0
# ...                     ...  ...                ...                ...
# DANT2                   0.0  ...                0.0                0.0
# KLHL13                  0.0  ...                0.0                0.0
# ZNF185              1.21865  ...           1.858828           2.052788
# L1CAM              0.784499  ...                0.0           1.480421
# MT-CO2             4.827483  ...           4.576131           5.530282
#
# barcode  TTGTTTGAGCTCATAC-1 TTTACGTTCAAGGCTT-1 TTTACTGCAGCTACAT-1  \
# Label                     7                  7                  3
# HES4               2.241301                0.0           1.883256
# ISG15              1.335489                0.0           1.050225
# C1QTNF12                0.0                0.0                0.0
# MFAP2              1.335489                0.0             1.7309
# ...                     ...                ...                ...
# DANT2              1.335489                0.0             1.7309
# KLHL13                  0.0                0.0            1.33169
# ZNF185             1.887631                0.0             1.7309
# L1CAM              1.335489                0.0           0.657078
# MT-CO2             4.043701           4.378127           3.898241
#
# barcode  TTTACTGTCATTACTC-1 TTTCACAGTGATATAG-1 TTTCACATCGATGCAT-1  \
# Label                    14                  3                  3
# HES4                2.67967           1.877891           1.520372
# ISG15              1.127936           0.802469                0.0
# C1QTNF12                0.0                0.0                0.0
# MFAP2                   0.0           0.479658           1.520372
# ...                     ...                ...                ...
# DANT2               0.71522           0.479658           2.097755
# KLHL13                  0.0                0.0           1.520372
# ZNF185                  0.0           0.479658           2.097755
# L1CAM               0.71522           0.479658           2.097755
# MT-CO2             4.770679           4.738441           3.781621
#
# barcode  TTTCATGTCCCTCTAG-1 TTTGACTGTTCCGGTG-1
# Label                     7                  3
# HES4               1.049049           0.763774
# ISG15                   0.0           0.763774
# C1QTNF12                0.0                0.0
# MFAP2              1.049049           0.763774
# ...                     ...                ...
# DANT2                   0.0                0.0
# KLHL13                  0.0           0.763774
# ZNF185                  0.0           2.199947
# L1CAM                   0.0                0.0
# MT-CO2             4.634937           4.065913
#
# [581 rows x 10594 columns]

# %% [markdown]
# ## Print the matrix and save to csv

# %%
# Assuming count_df is your DataFrame
# Example: count_df = pd.DataFrame(...)

# If your first column 'barcode' is not the index, set it as index
if count_df.columns[0] == 'barcode':
    count_df = count_df.set_index('barcode')

# Directory where you want to save the file
directory = '../../data'

# Create the directory if it does not exist
if not os.path.exists(directory):
    os.makedirs(directory)

# File path for the csv file
file_path = os.path.join(directory, 'output.csv')

# Save the DataFrame to a csv file, including the index (barcode)
count_df.to_csv(file_path)

print(f"DataFrame saved to {file_path}")
# Out:
# DataFrame saved to ../../data/output.csv

# %%
count_df
# Out:
# barcode  AAACCCAGTAGGCTCC-1 AAACCCAGTCGCAACC-1 AAACCCATCCACAAGT-1  \
# Label                     1                 11                  5
# HES4               1.583742           1.817618                0.0
# ISG15                   0.0                0.0                0.0
# C1QTNF12                0.0           2.106576                0.0
# MFAP2                   0.0                0.0                0.0
# ...                     ...                ...                ...
# DANT2                   0.0           1.634275                0.0
# KLHL13                  0.0                0.0                0.0
# ZNF185                  0.0                0.0           1.291329
# L1CAM                   0.0                0.0                0.0
# MT-CO2             3.963516           3.207734            4.12172
#
# barcode  AAACGCTTCACTACGA-1 AAACGCTTCAGCCTCT-1 AAAGAACAGATACAGT-1  \
# Label                     8                  6                  1
# HES4               1.823131           0.470256           1.036066
# ISG15                   0.0           0.470256                0.0
# C1QTNF12                0.0                0.0                0.0
# MFAP2                   0.0                0.0                0.0
# ...                     ...                ...                ...
# DANT2                   0.0           1.946486           0.646608
# KLHL13                  0.0           1.030051           1.036066
# ZNF185             0.712088                0.0           0.646608
# L1CAM              0.712088                0.0                0.0
# MT-CO2             4.241672           4.708393           4.065095
#
# barcode  AAAGAACAGCCTCGTG-1 AAAGAACAGTAATCCC-1 AAAGAACCAACATCGT-1  \
# Label                     6                  8                  6
# HES4                0.88049           1.708302           2.782923
# ISG15                   0.0           0.918898           0.866574
# C1QTNF12                0.0                0.0           0.524357
# MFAP2                   0.0                0.0                0.0
# ...                     ...                ...                ...
# DANT2                   0.0                0.0                0.0
# KLHL13                  0.0           1.949632                0.0
# ZNF185                  0.0                0.0                0.0
# L1CAM               0.88049                0.0                0.0
# MT-CO2             4.807613           3.530574           5.400871
#
# barcode  AAAGAACGTCGCGGTT-1  ... TTGTGGATCTAGCAAC-1 TTGTTCACAGGTCAAG-1  \
# Label                     1  ...                  3                  3
# HES4                1.21865  ...           1.621794           2.052788
# ISG15                   0.0  ...                0.0                0.0
# C1QTNF12                0.0  ...                0.0                0.0
# MFAP2                   0.0  ...                0.0                0.0
# ...                     ...  ...                ...                ...
# DANT2                   0.0  ...                0.0                0.0
# KLHL13                  0.0  ...                0.0                0.0
# ZNF185              1.21865  ...           1.858828           2.052788
# L1CAM              0.784499  ...                0.0           1.480421
# MT-CO2             4.827483  ...           4.576131           5.530282
#
# barcode  TTGTTTGAGCTCATAC-1 TTTACGTTCAAGGCTT-1 TTTACTGCAGCTACAT-1  \
# Label                     7                  7                  3
# HES4               2.241301                0.0           1.883256
# ISG15              1.335489                0.0           1.050225
# C1QTNF12                0.0                0.0                0.0
# MFAP2              1.335489                0.0             1.7309
# ...                     ...                ...                ...
# DANT2              1.335489                0.0             1.7309
# KLHL13                  0.0                0.0            1.33169
# ZNF185             1.887631                0.0             1.7309
# L1CAM              1.335489                0.0           0.657078
# MT-CO2             4.043701           4.378127           3.898241
#
# barcode  TTTACTGTCATTACTC-1 TTTCACAGTGATATAG-1 TTTCACATCGATGCAT-1  \
# Label                    14                  3                  3
# HES4                2.67967           1.877891           1.520372
# ISG15              1.127936           0.802469                0.0
# C1QTNF12                0.0                0.0                0.0
# MFAP2                   0.0           0.479658           1.520372
# ...                     ...                ...                ...
# DANT2               0.71522           0.479658           2.097755
# KLHL13                  0.0                0.0           1.520372
# ZNF185                  0.0           0.479658           2.097755
# L1CAM               0.71522           0.479658           2.097755
# MT-CO2             4.770679           4.738441           3.781621
#
# barcode  TTTCATGTCCCTCTAG-1 TTTGACTGTTCCGGTG-1
# Label                     7                  3
# HES4               1.049049           0.763774
# ISG15                   0.0           0.763774
# C1QTNF12                0.0                0.0
# MFAP2              1.049049           0.763774
# ...                     ...                ...
# DANT2                   0.0                0.0
# KLHL13                  0.0           0.763774
# ZNF185                  0.0           2.199947
# L1CAM                   0.0                0.0
# MT-CO2             4.634937           4.065913
#
# [581 rows x 10594 columns]

# %% [markdown]
# # Test reading the Input PFA table

# %%
# !pwd
# Out:
# /home2/lumpi/Projects/single-cell_samantha/code/scripts

# %%
import pandas as pd

# Assuming 'path' is the path to your CSV file
path="../../data/output.csv" #Please insert correct file input name

# Read the CSV file, without considering any row as header initially
data = pd.read_csv(path, header=None)

# Manually set the second row as the header
data.columns = data.iloc[1].astype(str)

# Drop the first two rows now that headers are set
data = data.drop([0, 1])

# Reset the index of the DataFrame
data.reset_index(drop=True, inplace=True)

# Display the DataFrame to verify the header and the first few rows
print(data.head())

# %%
data
# Out:
# 1       Label                  1                  11         5  \
# 0        HES4  1.583741545677185  1.8176181316375732       0.0
# 1       ISG15                0.0                 0.0       0.0
# 2    C1QTNF12                0.0  2.1065757274627686       0.0
# 3       MFAP2                0.0                 0.0       0.0
# 4       PADI2                0.0                 0.0       0.0
# ..        ...                ...                 ...       ...
# 575     DANT2                0.0            1.634275       0.0
# 576    KLHL13                0.0                 0.0       0.0
# 577    ZNF185                0.0                 0.0  1.291329
# 578     L1CAM                0.0                 0.0       0.0
# 579    MT-CO2           3.963516            3.207734   4.12172
#
# 1                     8                  6                   1  \
# 0    1.8231309652328491  0.470255583524704  1.0360662937164307
# 1                   0.0  0.470255583524704                 0.0
# 2                   0.0                0.0                 0.0
# 3                   0.0                0.0                 0.0
# 4     0.712087869644165                0.0   2.112929344177246
# ..                  ...                ...                 ...
# 575                 0.0           1.946486            0.646608
# 576                 0.0           1.030051            1.036066
# 577            0.712088                0.0            0.646608
# 578            0.712088                0.0                 0.0
# 579            4.241672           4.708393            4.065095
#
# 1                    6                   8                   6  ...  \
# 0    0.880490243434906  1.7083015441894531  2.7829229831695557  ...
# 1                  0.0  0.9188977479934692  0.8665735125541687  ...
# 2                  0.0                 0.0  0.5243574976921082  ...
# 3                  0.0                 0.0                 0.0  ...
# 4                  0.0                 0.0                 0.0  ...
# ..                 ...                 ...                 ...  ...
# 575                0.0                 0.0                 0.0  ...
# 576                0.0            1.949632                 0.0  ...
# 577                0.0                 0.0                 0.0  ...
# 578            0.88049                 0.0                 0.0  ...
# 579           4.807613            3.530574            5.400871  ...
#
# 1                    3                  3                   7  \
# 0    1.621793508529663  2.052788496017456  2.2413008213043213
# 1                  0.0                0.0  1.3354885578155518
# 2                  0.0                0.0                 0.0
# 3                  0.0                0.0  1.3354885578155518
# 4                  0.0                0.0                 0.0
# ..                 ...                ...                 ...
# 575                0.0                0.0            1.335489
# 576                0.0                0.0                 0.0
# 577           1.858828           2.052788            1.887631
# 578                0.0           1.480421            1.335489
# 579           4.576131           5.530282            4.043701
#
# 1                     7                   3                  14  \
# 0                   0.0  1.8832560777664185  2.6796696186065674
# 1                   0.0  1.0502245426177979  1.1279358863830566
# 2                   0.0                 0.0                 0.0
# 3                   0.0  1.7308998107910156                 0.0
# 4    0.8673115968704224  1.3316901922225952                 0.0
# ..                  ...                 ...                 ...
# 575                 0.0              1.7309             0.71522
# 576                 0.0             1.33169                 0.0
# 577                 0.0              1.7309                 0.0
# 578                 0.0            0.657078             0.71522
# 579            4.378127            3.898241            4.770679
#
# 1                      3                   3                   7  \
# 0     1.8778905868530273  1.5203723907470703  1.0490491390228271
# 1     0.8024693727493286                 0.0                 0.0
# 2                    0.0                 0.0                 0.0
# 3    0.47965794801712036  1.5203723907470703  1.0490491390228271
# 4    0.47965794801712036                 0.0  2.1305789947509766
# ..                   ...                 ...                 ...
# 575             0.479658            2.097755                 0.0
# 576                  0.0            1.520372                 0.0
# 577             0.479658            2.097755                 0.0
# 578             0.479658            2.097755                 0.0
# 579             4.738441            3.781621            4.634937
#
# 1                     3
# 0    0.7637744545936584
# 1    0.7637744545936584
# 2                   0.0
# 3    0.7637744545936584
# 4    0.7637744545936584
# ..                  ...
# 575                 0.0
# 576            0.763774
# 577            2.199947
# 578                 0.0
# 579            4.065913
#
# [580 rows x 10595 columns]

# %% [markdown]
# # Download and Execute PFA related scripts

# %% [markdown]
# ## Download all PFA folder

# %%
# !git clone https://github.com/AC-PHD/Seurat_PFA_pipeline.git
# Out:
# Cloning into 'Seurat_PFA_pipeline'...
# remote: Enumerating objects: 247, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 247 (delta 49), reused 0 (delta 0), pack-reused 142
# Receiving objects: 100% (247/247), 562.21 KiB | 11.96 MiB/s, done.
# Resolving deltas: 100% (91/91), done.

# %% [markdown]
# # PFA 1:

# %% [markdown]
# ## go to folder Seurat_PFA_pipeline/06_PFA

# %%
### 01_Prepare_Data_et

# %%
### 02_PFA_gene_selectiion

# %%
### 03_Vaidtae_PFA_Results

# %% [markdown]
# # Load data

# %%
#pip install biomart

# %%
#pip install gseapy

# %%
import pandas as pd
import scanpy as sc
import numpy as np

# %%
import gseapy as gp

# %% [markdown]
# # Read data

# %%
import scanpy as sc

# %%
#adata = sc.read("/storage/users/sac43cg/res_Samantha_1/outs/per_sample_outs/time_adata.h5ad")
adata = sc.read("../../data//time_adata.h5ad")
#adata = sc.read("../../data//time_adata.h5ad")

# %%
## make trivial names unique
adata.var_names = adata.var_names.astype(str)
adata.var_names_make_unique()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 10594 × 2000
#     obs: 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'pct_cmo', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'leiden', 'leiden_combined', 'louvain', 'louvain_combined', 't', 'seg', 'edge', 't_sd', 'milestones', '43->144_lindev_sel', '43->30_lindev_sel', '82->30_lindev_sel'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'CMO', 'gene_symbol', 'mito', 'ribo', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', '43->144_rss', '43->30_rss', '82->30_rss', 'p_val', 'A', 'fdr', 'st', 'signi'
#     uns: '43->144_lindev_sel_colors', '43->30_lindev_sel_colors', '82->30_lindev_sel_colors', 'condition_colors', 'dendro_segments', 'draw_graph', 'graph', 'hvg', 'leiden', 'leiden_colors', 'leiden_combined_colors', 'log1p', 'louvain', 'louvain_colors', 'louvain_combined_colors', 'milestones_colors', 'neighbors', 'pca', 'ppt', 'pseudotime_list', 'seg_colors', 'stat_assoc_list', 'umap'
#     obsm: 'X_R', 'X_dendro', 'X_draw_graph_fa', 'X_palantir', 'X_pca', 'X_pca2d', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs.head()
# Out:
#                    condition  n_genes_by_counts  log1p_n_genes_by_counts  \
# barcode
# AAACCCAGTAGGCTCC-1    CTRL_1               3076                 8.031710
# AAACCCAGTCGCAACC-1    CTRL_1               4271                 8.359837
# AAACCCATCCACAAGT-1    CTRL_1               3517                 8.165648
# AAACGCTTCACTACGA-1    CTRL_1               4077                 8.313362
# AAACGCTTCAGCCTCT-1    CTRL_1               6263                 8.742574
#
#                     total_counts  log1p_total_counts  \
# barcode
# AAACCCAGTAGGCTCC-1         15109            9.623112
# AAACCCAGTCGCAACC-1         18912            9.847605
# AAACCCATCCACAAGT-1         14791            9.601842
# AAACGCTTCACTACGA-1         18788            9.841027
# AAACGCTTCAGCCTCT-1         32489           10.388688
#
#                     pct_counts_in_top_50_genes  pct_counts_in_top_100_genes  \
# barcode
# AAACCCAGTAGGCTCC-1                   54.359972                    65.514317
# AAACCCAGTCGCAACC-1                   58.422557                    66.296003
# AAACCCATCCACAAGT-1                   48.576595                    57.179024
# AAACGCTTCACTACGA-1                   50.601623                    60.215361
# AAACGCTTCAGCCTCT-1                   47.930883                    56.820337
#
#                     pct_counts_in_top_200_genes  pct_counts_in_top_500_genes  \
# barcode
# AAACCCAGTAGGCTCC-1                    73.540856                    81.846752
# AAACCCAGTCGCAACC-1                    72.210555                    78.996110
# AAACCCATCCACAAGT-1                    65.667786                    75.871868
# AAACGCTTCACTACGA-1                    68.136395                    76.612147
# AAACGCTTCAGCCTCT-1                    63.782934                    71.878976
#
#                       pct_cmo  ...  louvain  louvain_combined         t  seg  \
# barcode                        ...
# AAACCCAGTAGGCTCC-1  24.628355  ...        2                 2  0.006304   14
# AAACCCAGTCGCAACC-1  34.891727  ...        2                 2  0.342083   14
# AAACCCATCCACAAGT-1  23.580470  ...        5                 5  0.087838   14
# AAACGCTTCACTACGA-1  23.367459  ...        5                 5  0.017375   14
# AAACGCTTCAGCCTCT-1  24.847910  ...        6                 6  2.114481    8
#
#                       edge      t_sd milestones    43->144_lindev_sel  \
# barcode
# AAACCCAGTAGGCTCC-1   67|13  0.011758         43  putative progenitors
# AAACCCAGTCGCAACC-1   159|0  0.043323         43       putative bridge
# AAACCCATCCACAAGT-1   31|51  0.048672         43       putative bridge
# AAACGCTTCACTACGA-1    1|61  0.022052         43       putative bridge
# AAACGCTTCAGCCTCT-1  162|76  0.029623        162       putative bridge
#
#                        43->30_lindev_sel 82->30_lindev_sel
# barcode
# AAACCCAGTAGGCTCC-1  putative progenitors               NaN
# AAACCCAGTCGCAACC-1       putative bridge               NaN
# AAACCCATCCACAAGT-1       putative bridge               NaN
# AAACGCTTCACTACGA-1       putative bridge               NaN
# AAACGCTTCAGCCTCT-1                   NaN               NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# # Create dictionary

# %%
from biomart import BiomartServer

# Connect to the BioMart server
server = BiomartServer("http://ensembl.org/biomart")

# Select the human genes dataset
dataset = server.datasets['hsapiens_gene_ensembl']

# Query BioMart to get the translation from Ensembl ID to gene symbol
response = dataset.search({
    'attributes': ['ensembl_gene_id', 'external_gene_name'],
})

# Initialize an empty dictionary to store the mapping
ensembl_to_gene_name = {}

# Iterate through the response lines
for line in response.iter_lines():
    # Decode the line and split it into Ensembl ID and gene name
    decoded_line = line.decode('utf-8')
    ensembl_id, gene_name = decoded_line.split('\t')
    
    # Store the mapping in the dictionary
    ensembl_to_gene_name[ensembl_id] = gene_name

# Now, ensembl_to_gene_name is a dictionary with Ensembl IDs as keys and gene names as values.

# %% [markdown]
# # Individually define comparison : Define the Comparison and perform the GSEA analysis

# %% [markdown]
# ## Compare the conditons (testing)

# %%
# Create a new column 'cluster_category' based on the 'leiden' clusters
# Category 1: Clusters 3 and 15
# Category 2: Cluster 6
category_mapping = {'3': 'Category1', '15': 'Category1', '2': 'Category2', '7': 'Category2', '14': 'Category2'}
adata.obs['cluster_category'] = adata.obs['leiden'].map(category_mapping)

# Filter adata to include only the rows with the specified clusters (3, 15, 6)
adata = adata[adata.obs['cluster_category'].notnull()].copy()

# Optionally, you can check the first few rows to confirm
#print(adata.obs.head())
adata.obs.cluster_category
# Out:
# barcode
# AAGCGTTAGCCTCGTG-1    Category1
# ATCGGATGTTGAGGAC-1    Category2
# CATGGATGTGTATCCA-1    Category2
# CCACGAGTCCCATAAG-1    Category2
# CCGAACGAGAAACACT-1    Category2
#                         ...
# TTTACTGTCATTACTC-1    Category2
# TTTCACAGTGATATAG-1    Category1
# TTTCACATCGATGCAT-1    Category1
# TTTCATGTCCCTCTAG-1    Category2
# TTTGACTGTTCCGGTG-1    Category1
# Name: cluster_category, Length: 2896, dtype: object

# %%
# filter the adata bject for condition that are intended to compare
bdata = adata[adata.obs.cluster_category.isin(["Category1", "Category2"])].copy()

# %%
expression_df = bdata.to_df().T
#expression_df

# %%
expression_df

# %%
## perfrom GSEA anaylsis for the selected comparisons

res = gp.gsea(data=expression_df,
    gene_sets="Reactome_2022",
    cls=bdata.obs.cluster_category,
    permutation_num=1000,
   # permutation_type='phenotype',
    outdir=None,
    method='s2n', # signal_to_noise
    threads= 16)

# %%
# print head results
res.res2d.head()
print(res.res2d.head())

# Visualize the top pathways
terms = res.res2d.Term
axs = res.plot(terms[:10], show_ranking=False, legend_kws={'loc': (1.05, 0)}, )

# %% [markdown]
# ## Compare the Clusters (milestones, leiden)

# %% [markdown]
# #### Define the comparisons

# %%
# Define a function to label clusters:
# e.g. 5/11 to 2/16 
def label_clusters(cluster):
    if cluster in ["2","7","14"]:
        return "0"
    elif cluster in ["3","15"]:
        return "1"
    else:
        return "NA"  # This label will be used to filter out other clusters

# Create a new categorical column for comparison
adata.obs['compare_clusters'] = adata.obs['leiden'].map(label_clusters)

# Subset the data for only the two groups you're comparing
bdata = adata[adata.obs.compare_clusters.isin(["0", "1"])].copy()

# sort indices to define the direction of comparison (could for interpretation of the results :)
sorted_indices = bdata.obs.sort_values(by='compare_clusters').index
bdata = bdata[sorted_indices]

# create a dataframe from bdata and translae ensembl ID to symbol (if not done before!!)
expression_df = bdata.to_df().T

# %%
expression_df
# Out:
# barcode          TCCATCGGTCCGAAAG-1  GTGAGCCTCCTCTCTT-1  TACATTCAGCTAGTTC-1  \
# feature_id
# ENSG00000188290            1.878265            1.481677            2.686580
# ENSG00000187608            0.000000            0.757736            0.000000
# ENSG00000224969            0.000000            0.000000            0.000000
# ENSG00000184163            0.000000            0.000000            0.000000
# ENSG00000049249            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# ENSG00000198883            0.000000            0.000000            0.000000
# ENSG00000182492            0.000000            0.000000            0.000000
# ENSG00000067842            0.000000            0.000000            0.000000
# ENSG00000198910            1.046400            0.000000            0.000000
# ENSG00000198712            4.536560            4.343032            5.249309
#
# barcode          TACAGGTGTGCGGCTT-1  GTGCTTCCAGTAACAA-1  TACAGGTAGATAGTGT-1  \
# feature_id
# ENSG00000188290            2.161048            0.627379            2.003533
# ENSG00000187608            0.000000            1.009924            0.000000
# ENSG00000224969            0.000000            0.000000            0.000000
# ENSG00000184163            0.000000            0.000000            0.000000
# ENSG00000049249            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# ENSG00000198883            0.000000            0.000000            0.000000
# ENSG00000182492            0.000000            0.000000            0.000000
# ENSG00000067842            0.000000            0.000000            0.000000
# ENSG00000198910            0.000000            1.830367            0.000000
# ENSG00000198712            4.417906            5.192416            4.143352
#
# barcode          TACACCCGTAGTGGCA-1  TACAACGAGCCATTTG-1  TACAACGAGCATTGAA-1  \
# feature_id
# ENSG00000188290            2.094867            2.772442            2.385169
# ENSG00000187608            0.000000            0.000000            0.000000
# ENSG00000224969            0.000000            0.000000            0.000000
# ENSG00000184163            0.000000            0.000000            0.000000
# ENSG00000049249            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# ENSG00000198883            0.000000            0.000000            0.000000
# ENSG00000182492            0.000000            1.627331            0.000000
# ENSG00000067842            0.000000            0.000000            0.000000
# ENSG00000198910            0.000000            0.000000            0.000000
# ENSG00000198712            4.897751            4.330579            3.522520
#
# barcode          TAATCTCGTAAGTTGA-1  ...  TGACGCGCATGTGCCG-1  \
# feature_id                           ...
# ENSG00000188290            1.339365  ...            2.763528
# ENSG00000187608            0.000000  ...            1.092177
# ENSG00000224969            0.000000  ...            0.000000
# ENSG00000184163            0.000000  ...            0.000000
# ENSG00000049249            0.000000  ...            0.000000
# ...                             ...  ...                 ...
# ENSG00000198883            0.000000  ...            0.000000
# ENSG00000182492            0.000000  ...            0.000000
# ENSG00000067842            0.000000  ...            0.000000
# ENSG00000198910            0.878925  ...            0.000000
# ENSG00000198712            4.362551  ...            4.467779
#
# barcode          TCTTAGTTCCAGCCTT-1  TCTGCCACATGGTGGA-1  TCTCTGGTCTCCTACG-1  \
# feature_id
# ENSG00000188290            0.000000            1.813863            1.824568
# ENSG00000187608            0.000000            0.706468            0.000000
# ENSG00000224969            0.000000            0.000000            0.000000
# ENSG00000184163            0.000000            0.000000            0.000000
# ENSG00000049249            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# ENSG00000198883            0.000000            0.000000            0.000000
# ENSG00000182492            2.006669            0.000000            0.000000
# ENSG00000067842            0.000000            0.000000            0.000000
# ENSG00000198910            0.000000            0.706468            0.000000
# ENSG00000198712            4.212589            3.020892            4.620409
#
# barcode          TCTATCACAGCGCGTT-1  TCTAACTGTCTACATG-1  TCGTAGATCCTTTGAT-1  \
# feature_id
# ENSG00000188290            2.867370            2.131317            1.399845
# ENSG00000187608            0.000000            0.910350            0.000000
# ENSG00000224969            0.000000            0.000000            0.000000
# ENSG00000184163            0.000000            0.000000            0.000000
# ENSG00000049249            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# ENSG00000198883            0.000000            0.000000            0.000000
# ENSG00000182492            0.000000            0.000000            0.000000
# ENSG00000067842            0.000000            0.000000            0.000000
# ENSG00000198910            1.638545            0.000000            0.927146
# ENSG00000198712            4.405250            4.320943            3.108257
#
# barcode          TCGGTCTCATGTGTCA-1  TGACCCTGTGTATTGC-1  TTTGACTGTTCCGGTG-1
# feature_id
# ENSG00000188290            2.031740            2.243843            0.763774
# ENSG00000187608            0.000000            0.499819            0.763774
# ENSG00000224969            0.000000            0.000000            0.000000
# ENSG00000184163            0.000000            0.000000            0.000000
# ENSG00000049249            0.000000            0.000000            0.000000
# ...                             ...                 ...                 ...
# ENSG00000198883            0.000000            0.000000            0.000000
# ENSG00000182492            0.000000            0.000000            0.000000
# ENSG00000067842            0.000000            0.000000            0.000000
# ENSG00000198910            1.689770            0.499819            0.000000
# ENSG00000198712            4.517145            2.918171            4.065913
#
# [2000 rows x 2896 columns]

# %% [markdown]
# ### If neccessary translate ID's to gene symbols

# %%
# Gen-IDs aus der Datei extrahieren
deg_gene_ids = expression_df.iloc[:, 0]
deg_gene_ids
# Out:
# feature_id
# ENSG00000188290    1.878265
# ENSG00000187608    0.000000
# ENSG00000224969    0.000000
# ENSG00000184163    0.000000
# ENSG00000049249    0.000000
#                      ...
# ENSG00000198883    0.000000
# ENSG00000182492    0.000000
# ENSG00000067842    0.000000
# ENSG00000198910    1.046400
# ENSG00000198712    4.536560
# Name: TCCATCGGTCCGAAAG-1, Length: 2000, dtype: float32

# %%
# translate ensembl_to_gene_name
mapping_dict = ensembl_to_gene_name

# Assuming expression_df is your DataFrame with Ensembl IDs (feature_id) as the index
# Map the Ensembl IDs in the index to gene symbols
new_index = expression_df.index.map(lambda x: mapping_dict.get(x, x))
new_index
# Out:
# Index(['HES4', 'ISG15', '', 'C1QTNF12', 'TNFRSF9', 'LINC01647', 'TNFRSF8',
#        'KAZN', 'SLC25A34-AS1', 'TMEM82',
#        ...
#        'FGF13', 'LINC00632', '', 'GABRA3', 'ZNF185', 'PNMA5', 'BGN', 'ATP2B3',
#        'L1CAM', 'MT-CO2'],
#       dtype='object', name='feature_id', length=2000)

# %%
# Replace the index of the original DataFrame
expression_df.index = new_index

# Rename the index name to 'gene_name'
expression_df.index.name = 'gene_name'

# %%
#expression_df.head()

# %% [markdown]
# ### Perform GSEA and visualize

# %%
#help(gp.gsea)

# %%
## Get the names for the pathway libraries and select one in the gsea function
#names = gp.get_library_name()
print(names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 ## Get the names for the pathway libraries and select one in the gsea function
#       2 #names = gp.get_library_name()
# ----> 3 print(names)
#
# NameError: name 'names' is not defined

# %%
#bdata.obs.compare_clusters

# %%
# Now you can run GSEA on this filtered data, using the cluster2 label:
# When you are running GSEA, make sure to use the new cluster2 la
res = gp.gsea(data=expression_df,
              gene_sets="GO_Biological_Process_2023",
              #gene_sets="Reactome_2022",
              cls=bdata.obs.compare_clusters, 
              permutation_num=1000,
              outdir=None,
              min_size= 50, 
              max_size = 400,
              method='log2_ratio_of_classes', 
              threads=26)
# Out:
# 2024-01-16 11:01:38,501 [WARNING] Dropping duplicated gene names, only keep the first values

# %%
# print head results
print(res.res2d.head(15))
# Out:
#     Name                                               Term        ES  \
# 0   gsea          Protein Modification Process (GO:0036211) -0.627894
# 1   gsea               Protein Phosphorylation (GO:0006468) -0.563416
# 2   gsea  Regulation Of Cell Population Proliferation (G... -0.545836
# 3   gsea  Negative Regulation Of Cellular Process (GO:00... -0.441802
# 4   gsea  Positive Regulation Of Cell Population Prolife...   -0.4755
# 5   gsea  Negative Regulation Of Apoptotic Process (GO:0... -0.518149
# 6   gsea  Negative Regulation Of DNA-templated Transcrip...  -0.43763
# 7   gsea  Positive Regulation Of Cellular Process (GO:00... -0.415961
# 8   gsea  Negative Regulation Of Cell Population Prolife... -0.339149
# 9   gsea  Positive Regulation Of Transcription By RNA Po...  0.487084
# 10  gsea   Positive Regulation Of MAPK Cascade (GO:0043410) -0.421997
# 11  gsea  Regulation Of Transcription By RNA Polymerase ... -0.323776
# 12  gsea  Cellular Response To Oxygen-Containing Compoun... -0.216981
# 13  gsea  Positive Regulation Of DNA-templated Transcrip...  0.380812
# 14  gsea            Nervous System Development (GO:0007399)  0.385242
#
#          NES NOM p-val FDR q-val FWER p-val   Tag %  Gene %  \
# 0  -1.218718  0.194872       1.0   0.529412    8/70   9.83%
# 1  -1.185744  0.315789       1.0    0.55934   13/51  22.14%
# 2  -1.152795   0.22973       1.0   0.590299  18/106  13.28%
# 3  -1.089095  0.311111       1.0   0.670795   21/77  28.12%
# 4  -1.019536  0.439024       1.0   0.796698   21/65  27.86%
# 5  -1.003635  0.471616       1.0   0.809082   15/59  22.59%
# 6  -0.878843  0.558233       1.0   0.908153   23/86  29.69%
# 7  -0.864919  0.813253       1.0   0.918473   22/77  24.02%
# 8  -0.848062  0.638514       1.0   0.934985   27/57  41.02%
# 9   0.798549  0.839566       1.0        1.0   11/78  15.95%
# 10 -0.733835  0.876761       1.0   0.988648   21/53  33.53%
# 11 -0.718235       1.0       1.0    0.98968  49/143  41.08%
# 12  -0.66738  0.937984       1.0   0.993808   25/54  46.48%
# 13  0.652992   0.99061       1.0        1.0  44/102  38.41%
# 14  0.646057  0.998737       1.0        1.0   30/60  36.78%
#
#                                            Lead_genes
# 0      EPB42;DUSP26;CDK1;BIRC5;CDCA8;MELK;AURKA;CCL11
# 1   CDK1;BIRC5;CDCA8;MELK;CLSPN;AURKA;CCL11;ABI3;P...
# 2   CHRM1;WNT1;TMIGD1;EDN2;CDKN3;KIF14;BIRC5;PRC1;...
# 3   SOX17;CDKN3;IFIT3;FABP7;BMP5;ACTL6B;AGR2;EREG;...
# 4   WNT1;EDN2;KIF14;BIRC5;PRC1;KIF20B;CCL5;BMP5;AC...
# 5   WNT1;TMIGD1;CDK1;KIF14;BIRC5;FFAR4;IFIT3;SFN;P...
# 6   IKZF1;DUSP26;LHX9;H1-5;DEPDC1;BIRC5;HMGB2;CENP...
# 7   WNT1;DUSP26;EDN2;KIF14;BIRC5;HBG2;CCL19;PRC1;K...
# 8   CDKN3;IFIT3;FABP7;BMP5;EREG;CYP1B1;IL1B;CXCL1;...
# 9   PAX3;RXRG;ELF3;SP7;GATA1;PRRX1;INHBA;PRKN;RORB...
# 10  FGB;CCL19;FFAR4;FGG;HTR2C;CCL7;CCL5;CCL11;CD24...
# 11  IKZF1;SOX17;DUSP26;LHX9;H1-5;HMGB2;CKAP2;ATAD2...
# 12  HMGB2;ECT2;IL1B;CXCL1;IL1A;H2AZ1;PDE4B;CLU;CRH...
# 13  PAX3;RXRG;ELF3;SP7;GATA1;EGF;PRRX1;INHBA;PRKN;...
# 14  MOBP;NOTO;NTF3;POU6F2;PCDHB4;SOX6;NRCAM;PTN;BR...

# %%
# Visualize the top pathways
terms = res.res2d.Term
print(terms)
axs = res.plot(terms[:16], show_ranking=False, legend_kws={'loc': (1.05, 0)}, )
# Out:
# 0             Protein Modification Process (GO:0036211)
# 1                  Protein Phosphorylation (GO:0006468)
# 2     Regulation Of Cell Population Proliferation (G...
# 3     Negative Regulation Of Cellular Process (GO:00...
# 4     Positive Regulation Of Cell Population Prolife...
# 5     Negative Regulation Of Apoptotic Process (GO:0...
# 6     Negative Regulation Of DNA-templated Transcrip...
# 7     Positive Regulation Of Cellular Process (GO:00...
# 8     Negative Regulation Of Cell Population Prolife...
# 9     Positive Regulation Of Transcription By RNA Po...
# 10     Positive Regulation Of MAPK Cascade (GO:0043410)
# 11    Regulation Of Transcription By RNA Polymerase ...
# 12    Cellular Response To Oxygen-Containing Compoun...
# 13    Positive Regulation Of DNA-templated Transcrip...
# 14              Nervous System Development (GO:0007399)
# 15    Positive Regulation Of Gene Expression (GO:001...
# 16    Negative Regulation Of Transcription By RNA Po...
# 17            Regulation Of Cell Migration (GO:0030334)
# 18           Regulation Of Gene Expression (GO:0010468)
# 19         Regulation Of Apoptotic Process (GO:0042981)
# 20    Regulation Of DNA-templated Transcription (GO:...
# 21    Positive Regulation Of Cell Migration (GO:0030...
# 22    Positive Regulation Of Intracellular Signal Tr...
# 23    Positive Regulation Of Protein Phosphorylation...
# Name: Term, dtype: object

# %% [markdown]
# ### Get the genes in the pathway

# %%
data = res.res2d
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# write to file location
data.to_csv("../../data/res_gsea_go_TGFB_GEM_vs_TGFB.csv", index=False)

# %%
# Extracting lead_genes
lead_genes = data['Lead_genes'].head(15)

# Printing the lead_genes
for i, genes in enumerate(lead_genes, 1):
    print(f"Row {i} Lead Genes: {genes}")
# Out:
# Row 1 Lead Genes: EPB42;DUSP26;CDK1;BIRC5;CDCA8;MELK;AURKA;CCL11
# Row 2 Lead Genes: CDK1;BIRC5;CDCA8;MELK;CLSPN;AURKA;CCL11;ABI3;PRKCH;DCLK1;EPHA7;PRKG1;EPHA6
# Row 3 Lead Genes: CHRM1;WNT1;TMIGD1;EDN2;CDKN3;KIF14;BIRC5;PRC1;HMGB2;KIF20B;IFIT3;FABP7;BMP5;ACTL6B;EREG;VIPR1;CYP1B1;IL1B
# Row 4 Lead Genes: SOX17;CDKN3;IFIT3;FABP7;BMP5;ACTL6B;AGR2;EREG;CYP1B1;IL1B;FHL1;CXCL1;IL1A;CLU;NRG1;CRYAB;CDA;CDKN1A;E2F7;ADAMTS1;UMOD
# Row 5 Lead Genes: WNT1;EDN2;KIF14;BIRC5;PRC1;KIF20B;CCL5;BMP5;ACTL6B;EREG;VIPR1;IL1B;PRKCH;AREG;NRG1;FOSL1;EDN1;CDKN1A;ID2;CHRD;LAMC2
# Row 6 Lead Genes: WNT1;TMIGD1;CDK1;KIF14;BIRC5;FFAR4;IFIT3;SFN;PRKCH;ARL6IP1;DKK1;CLU;CRYAB;BIRC3;KRT18
# Row 7 Lead Genes: IKZF1;DUSP26;LHX9;H1-5;DEPDC1;BIRC5;HMGB2;CENPF;NKX6-2;EREG;DACH1;LEFTY1;DKK1;NRG1;CRYAB;EDN1;FOXP2;ID3;PRICKLE1;ID2;E2F7;TENM2;BMP6
# Row 8 Lead Genes: WNT1;DUSP26;EDN2;KIF14;BIRC5;HBG2;CCL19;PRC1;KIF20B;SAA1;CCL5;BMP5;ACTL6B;EREG;VIPR1;IL1B;AREG;NID1;NRG1;FOSL1;EDN1;IBSP
# Row 9 Lead Genes: CDKN3;IFIT3;FABP7;BMP5;EREG;CYP1B1;IL1B;CXCL1;IL1A;NRG1;CDKN1A;E2F7;ADAMTS1;UMOD;TGFB2;APOE;HES1;ITGA1;ERBB4;WNT9A;SFRP1;P3H2;TNFAIP3;MAGI2;DDAH1;HMOX1;IRF1
# Row 10 Lead Genes: PAX3;RXRG;ELF3;SP7;GATA1;PRRX1;INHBA;PRKN;RORB;PBX1;KLF2
# Row 11 Lead Genes: FGB;CCL19;FFAR4;FGG;HTR2C;CCL7;CCL5;CCL11;CD24;IL1B;NRG1;CCL20;EDN1;GDF15;SEMA7A;P2RY6;CCL2;TGFB2;APOE;FLT1;CD4
# Row 12 Lead Genes: IKZF1;SOX17;DUSP26;LHX9;H1-5;HMGB2;CKAP2;ATAD2;HSF5;NKX6-2;BMP5;ACTL6B;NOS1;NR3C2;DACH1;LEFTY1;DKK1;H2AZ1;PAX5;ETV4;PKNOX2;FOSL1;WNT7A;CEBPD;LMO7;EDN1;FOXP2;ID3;ID2;TCF4;E2F7;TENM2;BMP6;POU2F3;MED12L;PBX3;GAL;HES1;ANKRD1;WWOX;MEF2C;CRY1;GADD45A;FOXS1;AUTS2;BACH2;PPARD;IRF1;CREB5
# Row 13 Lead Genes: HMGB2;ECT2;IL1B;CXCL1;IL1A;H2AZ1;PDE4B;CLU;CRHBP;P2RY6;SIRPA;CCL2;LY96;ANKRD1;WNT9A;SFRP1;MEF2C;TNFAIP3;TGM2;PTK7;PRKD1;SESN2;PF4;ABL2;SERPINE1
# Row 14 Lead Genes: PAX3;RXRG;ELF3;SP7;GATA1;EGF;PRRX1;INHBA;PRKN;RORB;MAFB;PBX1;KLF2;RUNX2;BCL11B;TNF;IGF2;ATF3;HEY1;SUPT3H;CAPRIN2;VEGFA;KLF7;EGR1;FOS;MICAL2;RUNX1;NFATC2;MAML3;BCAS3;HIVEP3;HMGA2;MMP12;JAG1;JUNB;RORA;CITED2;SOX4;GLIS3;LBH;TGFBR1;SNAI1;PDGFB;APBB2
# Row 15 Lead Genes: MOBP;NOTO;NTF3;POU6F2;PCDHB4;SOX6;NRCAM;PTN;BRINP3;GRIK1;SLITRK6;NAV3;KALRN;INHBA;PRKN;NLGN1;LSAMP;DSCAML1;CHRM3;NOG;EPHB1;VEGFA;NAV1;SEMA5A;JARID2;FN1;JAG1;SOX4;SPOCK1;TGFBR1

# %% [markdown]
# ### Get the logFC changes for the comparison or genes?

# %%
#adata = sc.read("/storage/users/sac43cg/res_Samantha_1/outs/per_sample_outs/time_adata.h5ad")
adata = sc.read("../../data/time_adata.h5ad")

# %%
## make trivial names unique
adata.var_names = adata.var_names.astype(str)
adata.var_names_make_unique()

# %%
adata.var_names
# Out:
# Index(['ENSG00000188290', 'ENSG00000187608', 'ENSG00000224969',
#        'ENSG00000184163', 'ENSG00000049249', 'ENSG00000235643',
#        'ENSG00000120949', 'ENSG00000189337', 'ENSG00000224459',
#        'ENSG00000162460',
#        ...
#        'ENSG00000129682', 'ENSG00000203930', 'ENSG00000284377',
#        'ENSG00000011677', 'ENSG00000147394', 'ENSG00000198883',
#        'ENSG00000182492', 'ENSG00000067842', 'ENSG00000198910',
#        'ENSG00000198712'],
#       dtype='object', name='feature_id', length=2000)

# %%
import scanpy as sc

# Define a function to label clusters:
# e.g. 5/11 to 2/16 
def label_clusters(cluster):
    if cluster in ["144"]:
        return "0"
    elif cluster in ["43"]:
        return "1"
    else:
        return "NA"  # This label will be used to filter out other clusters

# Create a new categorical column for comparison
adata.obs['compare_clusters'] = adata.obs['milestones'].map(label_clusters)

# Subset the data for only the two groups you're comparing
bdata = adata[adata.obs.compare_clusters.isin(["0", "1"])].copy()

# sort indices to define the direction of comparison (could for interpretation of the results :)
sorted_indices = bdata.obs.sort_values(by='compare_clusters').index
bdata = bdata[sorted_indices]

# Mark these two conditions in the subset
bdata.obs['group_comparison'] = bdata.obs['compare_clusters'].astype(str)
# Out:
# /tmp/ipykernel_1479223/3665015073.py:24: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   bdata.obs['group_comparison'] = bdata.obs['compare_clusters'].astype(str)

# %%
bdata
# Out:
# AnnData object with n_obs × n_vars = 3380 × 2000
#     obs: 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'pct_cmo', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'leiden', 'leiden_combined', 'louvain', 'louvain_combined', 't', 'seg', 'edge', 't_sd', 'milestones', '43->144_lindev_sel', '43->30_lindev_sel', '82->30_lindev_sel', 'compare_clusters', 'group_comparison'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'CMO', 'gene_symbol', 'mito', 'ribo', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', '43->144_rss', '43->30_rss', '82->30_rss', 'p_val', 'A', 'fdr', 'st', 'signi'
#     uns: '43->144_lindev_sel_colors', '43->30_lindev_sel_colors', '82->30_lindev_sel_colors', 'condition_colors', 'dendro_segments', 'draw_graph', 'graph', 'hvg', 'leiden', 'leiden_colors', 'leiden_combined_colors', 'log1p', 'louvain', 'louvain_colors', 'louvain_combined_colors', 'milestones_colors', 'neighbors', 'pca', 'ppt', 'pseudotime_list', 'seg_colors', 'stat_assoc_list', 'umap'
#     obsm: 'X_R', 'X_dendro', 'X_draw_graph_fa', 'X_palantir', 'X_pca', 'X_pca2d', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# #### sometimes the base of the logtransformation is not stored properly. this information can be added afterwards.

# %%
if 'log1p' in bdata.uns and 'base' not in bdata.uns['log1p']:
    bdata.uns['log1p']['base'] = np.e  # Assuming natural logarithm was used. Change accordingly if it was a different base.

# %%
bdata.uns['log1p']['base']
# Out:
# 2.718281828459045

# %%
# Now, perform differential expression analysis between the two groups
sc.tl.rank_genes_groups(bdata, 'group_comparison', method='wilcoxon')
#sc.tl.rank_genes_groups(bdata, 'grouping', method='wilcoxon', n_genes=bdata.shape[1])

# %%
sc.pl.rank_genes_groups(bdata)

# %%
# Convert result to dataframe
results = pd.DataFrame({
    'ID': bdata.uns['rank_genes_groups']['names']['0'],
    'log2FC': bdata.uns['rank_genes_groups']['logfoldchanges']['0'],
    'p.value': bdata.uns['rank_genes_groups']['pvals']['0'],
    'adjusted.p.value': bdata.uns['rank_genes_groups']['pvals_adj']['0']
})

# Convert ensembl IDs to gene symbols
results['symbol'] = results['ID'].map(ensembl_to_gene_name).fillna(results['ID'])

# Calculate basemean expression for genes present in adata.var_names
results['basemean'] = [
    (bdata[:, gene].X.sum() / bdata.shape[0]) if gene in bdata.var_names else 'NA' 
    for gene in results['ID']
]
# Assign comparison name
results['comparison'] = "CTRL_GEM vs." + "CTRL"

# %%
#bdata.uns['rank_genes_groups']

# %%
bdata
# Out:
# AnnData object with n_obs × n_vars = 3380 × 2000
#     obs: 'condition', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'pct_cmo', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'leiden', 'leiden_combined', 'louvain', 'louvain_combined', 't', 'seg', 'edge', 't_sd', 'milestones', '43->144_lindev_sel', '43->30_lindev_sel', '82->30_lindev_sel', 'compare_clusters', 'group_comparison'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'CMO', 'gene_symbol', 'mito', 'ribo', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', '43->144_rss', '43->30_rss', '82->30_rss', 'p_val', 'A', 'fdr', 'st', 'signi'
#     uns: '43->144_lindev_sel_colors', '43->30_lindev_sel_colors', '82->30_lindev_sel_colors', 'condition_colors', 'dendro_segments', 'draw_graph', 'graph', 'hvg', 'leiden', 'leiden_colors', 'leiden_combined_colors', 'log1p', 'louvain', 'louvain_colors', 'louvain_combined_colors', 'milestones_colors', 'neighbors', 'pca', 'ppt', 'pseudotime_list', 'seg_colors', 'stat_assoc_list', 'umap', 'rank_genes_groups'
#     obsm: 'X_R', 'X_dendro', 'X_draw_graph_fa', 'X_palantir', 'X_pca', 'X_pca2d', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
print(results)
# Out:
#                    ID    log2FC        p.value  adjusted.p.value symbol  \
# 0     ENSG00000148773  7.306439  9.211593e-305     1.158032e-301  MKI67
# 1     ENSG00000088325  6.469748  1.158032e-304     1.158032e-301   TPX2
# 2     ENSG00000164032  3.451744  2.231976e-304     1.487984e-301  H2AZ1
# 3     ENSG00000131747  7.214849  7.428702e-304     3.714351e-301  TOP2A
# 4     ENSG00000171848  6.404622  1.664356e-303     6.657423e-301   RRM2
# ...               ...       ...            ...               ...    ...
# 1995  ENSG00000128016 -2.790357  4.208151e-249     2.104076e-247  ZFP36
# 1996  ENSG00000120738 -5.956175  5.074082e-259     2.818934e-257   EGR1
# 1997  ENSG00000176171 -2.419455  1.890874e-272     1.350625e-270  BNIP3
# 1998  ENSG00000177410 -2.013472  1.389557e-279     1.068890e-277  ZFAS1
# 1999  ENSG00000234741 -3.053735  2.672344e-285     2.672344e-283   GAS5
#
#       basemean        comparison
# 0     0.382910  CTRL_GEM vs.CTRL
# 1     0.541646  CTRL_GEM vs.CTRL
# 2     1.500220  CTRL_GEM vs.CTRL
# 3     0.522631  CTRL_GEM vs.CTRL
# 4     0.363952  CTRL_GEM vs.CTRL
# ...        ...               ...
# 1995  2.366517  CTRL_GEM vs.CTRL
# 1996  1.479852  CTRL_GEM vs.CTRL
# 1997  2.608550  CTRL_GEM vs.CTRL
# 1998  3.471005  CTRL_GEM vs.CTRL
# 1999  2.973002  CTRL_GEM vs.CTRL
#
# [2000 rows x 7 columns]

# %%
# Reorder columns
results = results[['comparison', 'ID', 'symbol', 'basemean', 'log2FC', 'p.value', 'adjusted.p.value']]
results
# Out:
#             comparison               ID symbol  basemean    log2FC  \
# 0     CTRL_GEM vs.CTRL  ENSG00000148773  MKI67  0.382910  7.306439
# 1     CTRL_GEM vs.CTRL  ENSG00000088325   TPX2  0.541646  6.469748
# 2     CTRL_GEM vs.CTRL  ENSG00000164032  H2AZ1  1.500220  3.451744
# 3     CTRL_GEM vs.CTRL  ENSG00000131747  TOP2A  0.522631  7.214849
# 4     CTRL_GEM vs.CTRL  ENSG00000171848   RRM2  0.363952  6.404622
# ...                ...              ...    ...       ...       ...
# 1995  CTRL_GEM vs.CTRL  ENSG00000128016  ZFP36  2.366517 -2.790357
# 1996  CTRL_GEM vs.CTRL  ENSG00000120738   EGR1  1.479852 -5.956175
# 1997  CTRL_GEM vs.CTRL  ENSG00000176171  BNIP3  2.608550 -2.419455
# 1998  CTRL_GEM vs.CTRL  ENSG00000177410  ZFAS1  3.471005 -2.013472
# 1999  CTRL_GEM vs.CTRL  ENSG00000234741   GAS5  2.973002 -3.053735
#
#             p.value  adjusted.p.value
# 0     9.211593e-305     1.158032e-301
# 1     1.158032e-304     1.158032e-301
# 2     2.231976e-304     1.487984e-301
# 3     7.428702e-304     3.714351e-301
# 4     1.664356e-303     6.657423e-301
# ...             ...               ...
# 1995  4.208151e-249     2.104076e-247
# 1996  5.074082e-259     2.818934e-257
# 1997  1.890874e-272     1.350625e-270
# 1998  1.389557e-279     1.068890e-277
# 1999  2.672344e-285     2.672344e-283
#
# [2000 rows x 7 columns]

# %%
# write to file location
results.to_csv("../../data/diff_anaylsis_milestones_144_vs_30_results_df.csv", index=False)

# %%
# !pwd
# Out:
# /home2/lumpi/Projects/single-cell_samantha/code/scripts

# %% [markdown]
# ### Visualize the Pathway and the logFCs of the genes in R

# %% [raw]
# # execute R script 11_Pathway_anaylsis or similar

# %% [markdown]
# ### Some barcode annotation: Forgot why :)

# %%
# Translate Barcode to Conditons
barcode_to_condition = adata.obs['condition'].to_dict()
#barcode_to_condition

# Extract barcodes from GSEA results
#barcodes = res.res2d.index.tolist()
barcodes = res.res2d.columns.tolist()
barcodes

# Print terms
#terms

# %%
#help(gp.gsea)

# %% [markdown]
# ## Print Heatmap

# %%
from gseapy import heatmap
# plotting heatmap
i = 2
genes = res.res2d.Lead_genes[i].split(";")
# Make sure that ``ofname`` is not None, if you want to save your figure to disk


df_heat = res.heatmat.loc[genes]
barcode_to_condition

new_columns = df_heat.columns.map(barcode_to_condition.get)

# Assign the new column names back to the DataFrame
df_heat.columns = new_columns


ax = heatmap(df = df_heat, z_score=0, title=terms[i], figsize=(14,4))

gs_res = res
gs_res.heatmat.loc[genes]

# %% [markdown]
# ## Plot Bubbleplot

# %%
import matplotlib.pyplot as plt

from gseapy import dotplot
# to save your figure, make sure that ``ofname`` is not None
ax = dotplot(gs_res.res2d,
column="FDR q-val",
title='KEGG_2021_Human',
cmap=plt.cm.viridis,
size=5,
figsize=(4,5), cutoff=1)

# %% [markdown]
# ## Plot pathway network

# %%
import networkx as nx

# %%
res.res2d.head()
# Out:
#    Name                                               Term        ES  \
# 0  gsea    Extracellular Matrix Organization R-HSA-1474244 -0.607517
# 1  gsea     Signaling By TGFB Family Members R-HSA-9006936   -0.6769
# 2  gsea  Signaling By TGF-beta Receptor Complex R-HSA-1... -0.708324
# 3  gsea                   Collagen Formation R-HSA-1474290 -0.625634
# 4  gsea                Platelet Degranulation R-HSA-114608 -0.599753
#
#         NES NOM p-val FDR q-val FWER p-val  Tag %  Gene %  \
# 0 -2.183252  0.002257  0.005501      0.003  46/87  20.74%
# 1 -2.148591       0.0  0.005501      0.005  15/33   8.67%
# 2 -2.119574       0.0  0.006112      0.008  13/26   8.67%
# 3 -1.975415  0.002257  0.055464      0.059  22/35  25.57%
# 4 -1.969447       0.0  0.049505      0.065  15/32  16.13%
#
#                                           Lead_genes
# 0  SERPINE1;MMP2;COL1A1;COL5A1;PDGFA;LOX;ADAM19;P...
# 1  PMEPA1;SERPINE1;SKIL;ITGAV;BMPR2;SMURF2;ARHGEF...
# 2  PMEPA1;SERPINE1;SKIL;ITGAV;SMURF2;ARHGEF18;SMA...
# 3  COL1A1;COL5A1;LOX;COL22A1;PLOD2;COL7A1;P4HA3;C...
# 4  SERPINE1;PDGFA;PDGFB;TAGLN2;TUBA4A;IGF2;THBS1;...

# %%
 nodes, edges = gp.enrichment_map(res.res2d)

# %%
nodes.head()
# Out:
#           Name                                               Term        ES  \
# node_idx
# 0         gsea  Non-integrin membrane-ECM Interactions R-HSA-3... -0.632753
# 1         gsea                Platelet Degranulation R-HSA-114608 -0.599753
# 2         gsea  Collagen Biosynthesis And Modifying Enzymes R-...  -0.68322
# 3         gsea  TGF-beta Receptor Signaling Activates SMADs R-... -0.690859
# 4         gsea  Response To Elevated Platelet Cytosolic Ca2+ R... -0.586327
#
#                NES NOM p-val FDR q-val FWER p-val  Tag %  Gene %  \
# node_idx
# 0        -1.885516  0.006356  0.049963      0.137  10/22  11.40%
# 1        -1.969447       0.0  0.049505      0.065  15/32  16.13%
# 2        -1.935332  0.002227  0.046525      0.089  18/24  25.57%
# 3        -1.931101       0.0  0.042578      0.089  11/18  17.27%
# 4        -1.967738       0.0  0.041865      0.065  15/34  16.13%
#
#                                                  Lead_genes     p_inv  \
# node_idx
# 0         PDGFA;PDGFB;ITGAV;THBS1;SDC1;TGFB1;ITGB3;LAMB3...  1.301351
# 1         SERPINE1;PDGFA;PDGFB;TAGLN2;TUBA4A;IGF2;THBS1;...  1.305353
# 2         COL1A1;COL5A1;COL22A1;PLOD2;COL7A1;P4HA3;COL15...  1.332311
# 3         PMEPA1;ITGAV;SMURF2;SMAD7;TGFB1;LTBP3;TGFBR1;F...  1.370813
# 4         SERPINE1;PDGFA;PDGFB;TAGLN2;TUBA4A;IGF2;THBS1;...  1.378148
#
#           Hits_ratio
# node_idx
# 0           0.454545
# 1           0.468750
# 2           0.750000
# 3           0.611111
# 4           0.441176

# %%
edges.head()
# Out:
#    src_idx  targ_idx                                           src_name  \
# 0        0         1  Non-integrin membrane-ECM Interactions R-HSA-3...
# 1        0         3  Non-integrin membrane-ECM Interactions R-HSA-3...
# 2        0         4  Non-integrin membrane-ECM Interactions R-HSA-3...
# 3        0         5  Non-integrin membrane-ECM Interactions R-HSA-3...
# 4        0         6  Non-integrin membrane-ECM Interactions R-HSA-3...
#
#                                            targ_name  jaccard_coef  \
# 0                Platelet Degranulation R-HSA-114608      0.250000
# 1  TGF-beta Receptor Signaling Activates SMADs R-...      0.166667
# 2  Response To Elevated Platelet Cytosolic Ca2+ R...      0.250000
# 3  Signaling By TGF-beta Receptor Complex R-HSA-1...      0.150000
# 4    Extracellular Matrix Organization R-HSA-1474244      0.217391
#
#    overlap_coef                                      overlap_genes
# 0           0.5                      PDGFB,ITGB3,THBS1,PDGFA,TGFB1
# 1           0.3                                  ITGB3,ITGAV,TGFB1
# 2           0.5                      PDGFB,ITGB3,THBS1,PDGFA,TGFB1
# 3           0.3                                  ITGB3,ITGAV,TGFB1
# 4           1.0  PDGFB,ITGA2,ITGB3,THBS1,PDGFA,SDC2,LAMB3,ITGAV...

# %%
# build graph
G = nx.from_pandas_edgelist(edges,
    source='src_idx',
    target='targ_idx',
    edge_attr=['jaccard_coef', 'overlap_coef', 'overlap_genes'])

# %%
fig, ax = plt.subplots(figsize=(8, 8))
# init node cooridnates
pos=nx.layout.spiral_layout(G)
#node_size = nx.get_node_attributes()
# draw node
nx.draw_networkx_nodes(G,
pos=pos,
cmap=plt.cm.RdYlBu,
node_color=list(nodes.NES),
node_size=list(nodes.Hits_ratio *1000))
# draw node label
nx.draw_networkx_labels(G,
pos=pos,
labels=nodes.Term.to_dict())
# draw edge
edge_weight = nx.get_edge_attributes(G, 'jaccard_coef').values()
nx.draw_networkx_edges(G,
pos=pos,
width=list(map(lambda x: x*10, edge_weight)),
edge_color='#CDDBD4')
plt.show()

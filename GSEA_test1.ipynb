# %%
pip install biomart
# Out:
# Requirement already satisfied: biomart in ./miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages (0.9.2)
# Requirement already satisfied: requests>=2.2 in ./miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages (from biomart) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages (from requests>=2.2->biomart) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in ./miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages (from requests>=2.2->biomart) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages (from requests>=2.2->biomart) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages (from requests>=2.2->biomart) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gseapy as gp
import scanpy as sc
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import gseapy as gp
#       2 import scanpy as sc
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'gseapy'

# %%
# Pfad zur vorhandenen DEG-Liste (ersetzen Sie mit Ihrem Pfad)
deg_file = '/storage/users/sac43cg/res_Samantha_1/outs/DEGs/CTRL_1_vs_CTRL_2D/filtered_DEGs_with_names.csv'
with open(deg_file, 'r') as file:
    content = file.read()

print(content)
# Out:
# 0,1,gene_name
# ENSG00000115541,7.178151607513428,HSPE1
# ENSG00000164032,8.15096664428711,H2AZ1
# ENSG00000197451,3.845227241516113,HNRNPAB
# ENSG00000145494,4.307887554168701,NDUFS6
# ENSG00000239672,3.1633431911468506,NME1
# ENSG00000101361,3.0654754638671875,NOP56
# ENSG00000013275,6.213165760040283,PSMC4
# ENSG00000172115,3.1064414978027344,CYCS
# ENSG00000175166,2.366473436355591,PSMD2
# ENSG00000108561,2.808013439178467,C1QBP
# ENSG00000119969,3.1369690895080566,HELLS
# ENSG00000203760,2.691525459289551,CENPW
# ENSG00000092853,3.5478994846343994,CLSPN
# ENSG00000198830,4.907871246337891,HMGN2
# ENSG00000177700,15.492262840270996,POLR2L
# ENSG00000116560,2.170451164245605,SFPQ
# ENSG00000140365,2.0880725383758545,COMMD4
# ENSG00000186575,2.5383660793304443,NF2
# ENSG00000125944,1.9686099290847776,HNRNPR
# ENSG00000115053,4.8488383293151855,NCL
# ENSG00000168393,2.069314479827881,DTYMK
# ENSG00000112118,2.9309091567993164,MCM3
# ENSG00000103187,2.0972886085510254,COTL1
# ENSG00000120802,2.2987253665924072,TMPO
# ENSG00000189159,3.991332530975342,JPT1
# ENSG00000117395,2.0634148120880127,EBNA1BP2
# ENSG00000101057,2.657308578491211,MYBL2
# ENSG00000161547,1.8850808143615725,SRSF2
# ENSG00000164611,3.4519357681274414,PTTG1
# ENSG00000167900,2.342317581176758,TK1
# ENSG00000170860,1.8385157585144043,LSM3
# ENSG00000104738,2.854652643203736,MCM4
# ENSG00000138180,2.8407256603240967,CEP55
# ENSG00000128626,2.293337106704712,MRPS12
# ENSG00000233611,3.460679292678833,GBX2-AS1
# ENSG00000006712,2.34727144241333,PAF1
# ENSG00000161243,2.256398677825928,FBXO27
# ENSG00000122952,2.546708822250366,ZWINT
# ENSG00000120437,2.316354751586914,ACAT2
# ENSG00000072274,2.0943868160247803,TFRC
# ENSG00000171848,2.7472686767578125,RRM2
# ENSG00000172927,2.168485403060913,MYEOV
# ENSG00000110172,1.8827558755874636,CHORDC1
# ENSG00000088325,3.695667028427124,TPX2
# ENSG00000161980,1.8606377840042116,POLR3K
# ENSG00000128228,1.948911547660828,SDF2L1
# ENSG00000143924,2.050545215606689,EML4
# ENSG00000166508,2.107990264892578,MCM7
# ENSG00000075624,8.953252792358398,ACTB
# ENSG00000167641,8.136102676391602,PPP1R14A
# ENSG00000269893,-2.388862133026123,SNHG8
# ENSG00000196937,-2.8279194831848145,FAM3C
# ENSG00000113369,-3.4680440425872803,ARRDC3
# ENSG00000196352,-5.606405258178711,CD55
# ENSG00000165507,-4.27509355545044,DEPP1
# ENSG00000136156,-2.483433961868286,ITM2B
# ENSG00000167772,-4.377700805664063,ANGPTL4
# ENSG00000168209,-3.428007841110229,DDIT4
# ENSG00000148908,-2.1797754764556885,RGS10
# ENSG00000116285,-3.844952583312988,ERRFI1
# ENSG00000105220,-4.239960670471191,GPI
# ENSG00000111674,-3.2072911262512207,ENO2
# ENSG00000224032,-3.954452991485596,EPB41L4A-AS1
# ENSG00000197930,-4.852753639221191,ERO1A
# ENSG00000156976,-2.7450380325317383,EIF4A2
# ENSG00000128016,-8.403097152709961,ZFP36
# ENSG00000160888,-3.635861873626709,IER2
# ENSG00000171223,-4.136570930480957,JUNB
# ENSG00000146278,-3.255455493927002,PNRC1
# ENSG00000119950,-4.089643478393555,MXI1
# ENSG00000170345,-8.371362686157227,FOS
# ENSG00000114315,-5.985922336578369,HES1
# ENSG00000120738,-6.709409236907959,EGR1
# ENSG00000175061,-6.4406514167785645,SNHG29
# ENSG00000234741,-13.985456466674805,GAS5
# ENSG00000177410,-17.831899642944336,ZFAS1
# ENSG00000176171,-9.62469482421875,BNIP3
# ENSG00000122884,-5.219403266906738,P4HA1

# %%
#Neu
import pandas as pd
from urllib.parse import quote_plus

# Define the Biomart server and dataset name
server = "http://www.ensembl.org/biomart/martservice"
dataset_name = "hsapiens_gene_ensembl"

# %%
# Read gene IDs and logfold changes from the text file
gene_data_file = "/storage/users/sac43cg/res_Samantha_1/outs/DEGs/CTRL_1_vs_CTRL_2D/differentially_expressed_genes1.txt"
gene_df = pd.read_csv(gene_data_file, sep="\t", header=None, names=["ensembl_gene_id", "logfold_change"])


print(gene_df)
# Out:
#       ensembl_gene_id  logfold_change
# 0     ENSG00000164032        2.475180
# 1     ENSG00000197451        2.333972
# 2     ENSG00000101361        1.988561
# 3     ENSG00000203760        2.511373
# 4     ENSG00000119969        2.848776
# ...               ...             ...
# 1123  ENSG00000170345       -5.866974
# 1124  ENSG00000122884       -2.568223
# 1125  ENSG00000176171       -2.340556
# 1126  ENSG00000120738       -4.969254
# 1127  ENSG00000234741       -2.770039
#
# [1128 rows x 2 columns]

# %%
import pandas as pd

# Separate Ensembl gene IDs and logfold changes into separate DataFrames
ensembl_df = gene_df[["ensembl_gene_id"]]
logfold_df = gene_df[["logfold_change"]]

# Display the Ensembl gene IDs DataFrame
print(ensembl_df.head())

# Display the logfold changes DataFrame
print(logfold_df.head())
# Out:
#    ensembl_gene_id
# 0  ENSG00000164032
# 1  ENSG00000197451
# 2  ENSG00000101361
# 3  ENSG00000203760
# 4  ENSG00000119969
#    logfold_change
# 0        2.475180
# 1        2.333972
# 2        1.988561
# 3        2.511373
# 4        2.848776

# %%
# Split gene IDs into smaller batches
batch_size = 50
gene_batches = [ensembl_df[i:i+batch_size] for i in range(0, len(ensembl_df), batch_size)]

# %%
# Define a list to store Biomart data
biomart_data_list = []

# %%
# Iterate through each batch and query Biomart
for batch_df in gene_batches:
    # Create a comma-separated list of gene IDs for the query
    gene_id_list = ",".join(batch_df["ensembl_gene_id"].tolist())

    # Define the query
    query = f"""
        <Query virtualSchemaName="default" formatter="CSV" header="0">
            <Dataset name="{dataset_name}" interface="default">
                <Attribute name="ensembl_gene_id" />
                <Attribute name="external_gene_name" />
            </Dataset>
            <Filter name="ensembl_gene_id" value="{gene_id_list}" />
        </Query>
    """

    # Encode the query
    encoded_query = quote_plus(query)

    # Construct the URL
    url = f"{server}?query={encoded_query}"

    # Read the Biomart data into a DataFrame
    biomart_data_batch = pd.read_csv(url, sep="\t")

    # Append the batch data to the list
    biomart_data_list.append(biomart_data_batch)

# %%
print(biomart_data.head())
# Out:
#      ENSG00000210049,MT-TF
# 0  ENSG00000211459,MT-RNR1
# 1    ENSG00000210077,MT-TV
# 2  ENSG00000210082,MT-RNR2
# 3   ENSG00000209082,MT-TL1
# 4   ENSG00000198888,MT-ND1

# %%
import pandas as pd

# Annahme: Die Geninformationen sind in der ersten Spalte deines DataFrames
gene_names = biomart_data.iloc[:, 0].str.split(',', expand=True)[1]
print(gene_names)
# Out:
# 0          MT-RNR1
# 1            MT-TV
# 2          MT-RNR2
# 3           MT-TL1
# 4           MT-ND1
#             ...
# 1612640     CD24P1
# 1612641       DDI2
# 1612642     RSC1A1
# 1612643
# 1612644    PLEKHM2
# Name: 1, Length: 1612645, dtype: object

# %%
import pandas as pd

# Read gene IDs and logfold changes from the text file
gene_data_file = "/storage/users/sac43cg/res_Samantha_1/outs/DEGs/CTRL_1_vs_CTRL_2D/differentially_expressed_genes1.txt"
gene_df = pd.read_csv(gene_data_file, sep="\t", header=None, names=["ensembl_gene_id", "logfold_change"])

# Annahme: Die Geninformationen sind in der ersten Spalte deines DataFrames
gene_names = biomart_data.iloc[:, 0].str.split(',', expand=True)[1]

# Create a DataFrame from the gene_names Series
gene_names_df = gene_names.to_frame()

# Merge gene_names_df with logfold_df using their indices
merged_df = gene_names_df.merge(logfold_df, left_index=True, right_index=True)

# Display the merged DataFrame
print(merged_df.head())

# Display the merged DataFrame
print(merged_df.head())
# Out:
#          1  logfold_change
# 0  MT-RNR1        2.475180
# 1    MT-TV        2.333972
# 2  MT-RNR2        1.988561
# 3   MT-TL1        2.511373
# 4   MT-ND1        2.848776
#          1  logfold_change
# 0  MT-RNR1        2.475180
# 1    MT-TV        2.333972
# 2  MT-RNR2        1.988561
# 3   MT-TL1        2.511373
# 4   MT-ND1        2.848776

# %%
# Speichere die Gen-Namen in einer Textdatei
merged_df.to_csv('/storage/users/sac43cg/res_Samantha_1/outs/DEGs/CTRL_1_vs_CTRL_2D/differentially_expressed_genes_NEU.txt', index=False, header=False)

# %%
# Pfad zur vorhandenen DEG-Liste (ersetzen Sie mit Ihrem Pfad)
deg_file_Neu = '/storage/users/sac43cg/res_Samantha_1/outs/DEGs/CTRL_1_vs_CTRL_2D/differentially_expressed_genes_NEU.txt'

# %%
# Path to your GMT file with gene sets
gmt_file = "/storage/users/sac43cg/res_Samantha_1/outs/GMT.files/HALLMARK_GLYCOLYSIS.v2023.1.Hs.gmt"  # Replace with the path to your GMT file

# %%
with open(gmt_file, 'r') as gmt_file:
    gmt_content = gmt_file.read()

print(gmt_content)
# Out:
# HALLMARK_GLYCOLYSIS	https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_GLYCOLYSIS	ABCB6	ADORA2B	AGL	AGRN	AK3	AK4	AKR1A1	ALDH7A1	ALDH9A1	ALDOA	ALDOB	ALG1	ANG	ANGPTL4	ANKZF1	ARPP19	ARTN	AURKA	B3GALT6	B3GAT1	B3GAT3	B3GNT3	B4GALT1	B4GALT2	B4GALT4	B4GALT7	BIK	BPNT1	CACNA1H	CAPN5	CASP6	CD44	CDK1	CENPA	CHPF	CHPF2	CHST1	CHST12	CHST2	CHST4	CHST6	CITED2	CLDN3	CLDN9	CLN6	COG2	COL5A1	COPB2	CTH	CXCR4	CYB5A	DCN	DDIT4	DEPDC1	DLD	DPYSL4	DSC2	ECD	EFNA3	EGFR	EGLN3	ELF3	ENO1	ENO2	ERO1A	EXT1	EXT2	FAM162A	FBP2	FKBP4	FUT8	G6PD	GAL3ST1	GALE	GALK1	GALK2	GAPDHS	GCLC	GFPT1	GFUS	GLCE	GLRX	GMPPA	GMPPB	GNE	GNPDA1	GOT1	GOT2	GPC1	GPC3	GPC4	GPR87	GUSB	GYS1	GYS2	HAX1	HDLBP	HK2	HMMR	HOMER1	HS2ST1	HS6ST2	HSPA5	IDH1	IDUA	IER3	IGFBP3	IL13RA1	IRS2	ISG20	KDELR3	KIF20A	KIF2A	LCT	LDHA	LDHC	LHPP	LHX9	MDH1	MDH2	ME1	ME2	MED24	MERTK	MET	MIF	MIOX	MPI	MXI1	NANP	NASP	NDST3	NDUFV3	NOL3	NSDHL	NT5E	P4HA1	P4HA2	PAM	PAXIP1	PC	PDK3	PFKFB1	PFKP	PGAM1	PGAM2	PGK1	PGLS	PGM2	PHKA2	PKM	PKP2	PLOD1	PLOD2	PMM2	POLR3K	PPFIA4	PPIA	PPP2CB	PRPS1	PSMC4	PYGB	PYGL	QSOX1	RARS1	RBCK1	RPE	RRAGD	SAP30	SDC1	SDC2	SDC3	SDHC	SLC16A3	SLC25A10	SLC25A13	SLC35A3	SLC37A4	SOD1	SOX9	SPAG4	SRD5A3	STC1	STC2	STMN1	TALDO1	TFF3	TGFA	TGFBI	TKTL1	TPBG	TPI1	TPST1	TXN	UGP2	VCAN	VEGFA	VLDLR	XYLT2	ZNF292

# %%
# Führen Sie GSEA mit gseapy durch
result = gp.prerank(
    rnk='/storage/users/sac43cg/res_Samantha_1/outs/DEGs/CTRL_1_vs_CTRL_2D/differentially_expressed_genes_NEU.txt',  # Pfad zur vorhandenen DEG-Liste
    gene_sets="/storage/users/sac43cg/res_Samantha_1/outs/GMT.files/HALLMARK_GLYCOLYSIS.v2023.1.Hs.gmt",
    processes=16,  # Anzahl der CPU-Prozesse
    permutation_num=1000,  # Anzahl der Permutationen für die p-Wert-Berechnung
    outdir='/storage/users/sac43cg/res_Samantha_1/outs/DEGs/CTRL_1_vs_CTRL_2D/gsea_results'  # Ausgabeordner für Ergebnisse
)

# Zeigen Sie die Ergebnisse an
print(result.res2d)

#Ersetzen Sie 'path/to/deg_list.txt' durch den tatsächlichen Pfad zu Ihrer DEG-Liste und 'path/to/gmt_file.gmt' durch den Pfad zur GMT-Datei mit den Gene-Set-Definitionen.

#Dieses Skript verwendet die vorhandene DEG-Liste, um GSEA mit gseapy durchzuführen und speichert die Ergebnisse im angegebenen Ausgabeordner. Stellen Sie sicher, dass die DEG-Liste und die GMT-Datei korrekt vorhanden und zugänglich sind.
# Out:
# /tmp/ipykernel_438887/3294708760.py:2: DeprecationWarning: processes is deprecated; use threads
#   result = gp.prerank(
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 2
#       1 # Führen Sie GSEA mit gseapy durch
# ----> 2 result = gp.prerank(
#       3     rnk='/storage/users/sac43cg/res_Samantha_1/outs/DEGs/CTRL_1_vs_CTRL_2D/differentially_expressed_genes_NEU.txt',  # Pfad zur vorhandenen DEG-Liste
#       4     gene_sets="/storage/users/sac43cg/res_Samantha_1/outs/GMT.files/HALLMARK_GLYCOLYSIS.v2023.1.Hs.gmt",
#       5     processes=16,  # Anzahl der CPU-Prozesse
#       6     permutation_num=1000,  # Anzahl der Permutationen für die p-Wert-Berechnung
#       7     outdir='/storage/users/sac43cg/res_Samantha_1/outs/DEGs/CTRL_1_vs_CTRL_2D/gsea_results'  # Ausgabeordner für Ergebnisse
#       8 )
#      10 # Zeigen Sie die Ergebnisse an
#      11 print(result.res2d)
#
# File ~/miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages/gseapy/__init__.py:384, in prerank(rnk, gene_sets, outdir, pheno_pos, pheno_neg, min_size, max_size, permutation_num, weighted_score_type, ascending, threads, figsize, format, graph_num, no_plot, seed, verbose, *arg, **kwarg)
#     364     threads = kwarg["processes"]
#     365 pre = Prerank(
#     366     rnk,
#     367     gene_sets,
#    (...)
#     382     verbose,
#     383 )
# --> 384 pre.run()
#     385 return pre
#
# File ~/miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages/gseapy/gsea.py:429, in Prerank.run(self)
#     426 assert self.min_size <= self.max_size
#     428 # parsing rankings
# --> 429 dat2 = self.load_ranking()
#     430 assert len(dat2) > 1
#     431 self.ranking = dat2
#
# File ~/miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages/gseapy/gsea.py:381, in Prerank.load_ranking(self)
#     380 def load_ranking(self):
# --> 381     ranking = self._load_ranking(self.rnk)  # index is gene_names
#     382     if isinstance(ranking, pd.DataFrame):
#     383         # handle index is not gene_names
#     384         if ranking.index.dtype != "O":
#
# File ~/miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages/gseapy/base.py:109, in GSEAbase._load_ranking(self, rnk)
#     106     return rank_metric
#     107 # sort ranking values from high to low
#     108 rank_metric.sort_values(
# --> 109     by=rank_metric.columns[1], ascending=self.ascending, inplace=True
#     110 )
#     111 # drop na values
#     112 if rank_metric.isnull().any(axis=1).sum() > 0:
#
# File ~/miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages/pandas/core/indexes/base.py:5175, in Index.__getitem__(self, key)
#    5172 if is_integer(key) or is_float(key):
#    5173     # GH#44051 exclude bool, which would return a 2d ndarray
#    5174     key = com.cast_scalar_indexer(key)
# -> 5175     return getitem(key)
#    5177 if isinstance(key, slice):
#    5178     # This case is separated from the conditional above to avoid
#    5179     # pessimization com.is_bool_indexer and ndim checks.
#    5180     result = getitem(key)
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
#NOTE: To speed up, use gp.prerank instead with your own ranked list.
import gseapy as gp

# Load the ranked list of DEGs
deg_file_path = '/storage/users/sac43cg/res_Samantha_1/outs/DEGs/CTRL_1_vs_CTRL_2D/differentially_expressed_genes_NEU.txt'
# Load your data, e.g., using pandas, and extract class labels
# deg_data = pd.read_csv(deg_file_path)
# cls_labels = deg_data["class_labels_column_name"]

# Perform GSEA
res = gp.gsea(
    rnk=deg_file_path,
    gene_sets="path/to/gmt_file.gmt",
    cls=cls_labels,  # Provide your class labels here
    permutation_num=1000,
    permutation_type='phenotype',
    outdir=None,
    method='signal_to_noise',
    threads=16
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 5
#       1 #NOTE: To speed up, use gp.prerank instead with your own ranked list.
#       2 res = gp.gsea(
#       3     rnk=deg_file,  # Provide the path to your ranked list (DEG file)
#       4     gene_sets=gmt_file,
# ----> 5     cls=deg_file.obs.stim,  # Using class labels from the obs object
#       6     permutation_num=1000,
#       7     permutation_type='phenotype',
#       8     outdir=None,
#       9     method='signal_to_noise',  # Use the full method name
#      10     threads=16
#      11 )
#
# AttributeError: 'str' object has no attribute 'obs'

# %%
import gseapy as gp
import pandas as pd

# Load your data
deg_data = pd.read_csv("/storage/users/sac43cg/res_Samantha_1/outs/DEGs/CTRL_1_vs_CTRL_2D/differentially_expressed_genes_NEU.txt", header=None)

# Assuming your data is structured as [gene_name, ranking_score] separated by commas
# You can extract gene names and ranking scores
gene_names = deg_data[0]
ranking_scores = deg_data[1].astype(float)

# Create a DataFrame with gene names and ranking scores
ranked_genes = pd.DataFrame({"gene_name": gene_names, "ranking_score": ranking_scores})

# Perform GSEA using prerank
res = gp.prerank(
    rnk=ranked_genes,  # Provide the DataFrame with gene names and ranking scores
    gene_sets="/storage/users/sac43cg/res_Samantha_1/outs/GMT.files/HALLMARK_GLYCOLYSIS.v2023.1.Hs.gmt",
    threads=16,  # Use threads instead of processes
    permutation_num=1000,
    outdir=None
)
# Out:
# 2023-08-29 23:31:05,956 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2023-08-29 23:31:05,962 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2023-08-29 23:31:05,968 [ERROR] No gene sets passed through filtering condition !!!
# Hint 1: Try to lower min_size or increase max_size !
# Hint 2: Check gene symbols are identifiable to your gmt input.
# Hint 3: Gene symbols curated in Enrichr web services are all upcases.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 16
#      13 ranked_genes = pd.DataFrame({"gene_name": gene_names, "ranking_score": ranking_scores})
#      15 # Perform GSEA using prerank
# ---> 16 res = gp.prerank(
#      17     rnk=ranked_genes,  # Provide the DataFrame with gene names and ranking scores
#      18     gene_sets="/storage/users/sac43cg/res_Samantha_1/outs/GMT.files/HALLMARK_GLYCOLYSIS.v2023.1.Hs.gmt",
#      19     threads=16,  # Use threads instead of processes
#      20     permutation_num=1000,
#      21     outdir=None
#      22 )
#
# File ~/miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages/gseapy/__init__.py:384, in prerank(rnk, gene_sets, outdir, pheno_pos, pheno_neg, min_size, max_size, permutation_num, weighted_score_type, ascending, threads, figsize, format, graph_num, no_plot, seed, verbose, *arg, **kwarg)
#     364     threads = kwarg["processes"]
#     365 pre = Prerank(
#     366     rnk,
#     367     gene_sets,
#    (...)
#     382     verbose,
#     383 )
# --> 384 pre.run()
#     385 return pre
#
# File ~/miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages/gseapy/gsea.py:435, in Prerank.run(self)
#     433 self._logger.info("Parsing data files for GSEA.............................")
#     434 # filtering out gene sets and build gene sets dictionary
# --> 435 gmt = self.load_gmt(gene_list=dat2.index.values, gmt=self.gene_sets)
#     436 self.gmt = gmt
#     437 self._logger.info(
#     438     "%04d gene_sets used for further statistical testing....." % len(gmt)
#     439 )
#
# File ~/miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages/gseapy/base.py:233, in GSEAbase.load_gmt(self, gene_list, gmt)
#     226 msg = (
#     227     "No gene sets passed through filtering condition !!! \n"
#     228     + "Hint 1: Try to lower min_size or increase max_size !\n"
#     229     + "Hint 2: Check gene symbols are identifiable to your gmt input.\n"
#     230     + "Hint 3: Gene symbols curated in Enrichr web services are all upcases.\n"
#     231 )
#     232 self._logger.error(msg)
# --> 233 dict_head = "{ %s: [%s]}" % (subsets[0], genesets_dict[subsets[0]])
#     234 self._logger.error(
#     235     "The first entry of your gene_sets (gmt) look like this : %s"
#     236     % dict_head
#     237 )
#     238 raise LookupError(msg)
#
# KeyError: 'HALLMARK_GLYCOLYSIS'

# %%
# Convert gene symbols to Entrez IDs (if necessary)
# entrez_ids = convert_gene_symbols_to_entrez(adata.var_names)
# Extract expression values from AnnData
expression_data = np.array(adata.X)
gene_symbols = adata.var_names

# Create a gene universe (all genes in your dataset)
gene_universe = gene_symbols

# %%
# Path to your GMT file with gene sets
gmt_file = "/storage/users/sac43cg/res_Samantha_1/outs/GMT.files/HALLMARK_GLYCOLYSIS.v2023.1.Hs.gmt"  # Replace with the path to your GMT file

# %%
# Perform GSEA using gseapy
result = gp.prerank(
    rnk=expression_data,
    gene_sets=gmt_file,  # Replace with the path to your GMT file
    threads=4,  # Number of CPU threads to use
    permutation_num=1000,  # Number of permutations for p-value calculation
    outdir=None  # Output directory for results (None for no output)
)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Perform GSEA using gseapy
# ----> 2 result = gp.prerank(
#       3     rnk=expression_data,
#       4     gene_sets=gmt_file,  # Replace with the path to your GMT file
#       5     threads=4,  # Number of CPU threads to use
#       6     permutation_num=1000,  # Number of permutations for p-value calculation
#       7     outdir=None  # Output directory for results (None for no output)
#       8 )
#
# File ~/miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages/gseapy/__init__.py:384, in prerank(rnk, gene_sets, outdir, pheno_pos, pheno_neg, min_size, max_size, permutation_num, weighted_score_type, ascending, threads, figsize, format, graph_num, no_plot, seed, verbose, *arg, **kwarg)
#     364     threads = kwarg["processes"]
#     365 pre = Prerank(
#     366     rnk,
#     367     gene_sets,
#    (...)
#     382     verbose,
#     383 )
# --> 384 pre.run()
#     385 return pre
#
# File ~/miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages/gseapy/gsea.py:429, in Prerank.run(self)
#     426 assert self.min_size <= self.max_size
#     428 # parsing rankings
# --> 429 dat2 = self.load_ranking()
#     430 assert len(dat2) > 1
#     431 self.ranking = dat2
#
# File ~/miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages/gseapy/gsea.py:381, in Prerank.load_ranking(self)
#     380 def load_ranking(self):
# --> 381     ranking = self._load_ranking(self.rnk)  # index is gene_names
#     382     if isinstance(ranking, pd.DataFrame):
#     383         # handle index is not gene_names
#     384         if ranking.index.dtype != "O":
#
# File ~/miniconda3/envs/Gudruns_PDAC/lib/python3.11/site-packages/gseapy/base.py:103, in GSEAbase._load_ranking(self, rnk)
#     101     rank_metric = pd.read_table(rnk, header=None, sep=sep)
#     102 else:
# --> 103     raise Exception("Error parsing gene ranking values!")
#     105 if rank_metric.select_dtypes(np.number).shape[1] > 1:
#     106     return rank_metric
#
# Exception: Error parsing gene ranking values!

# %%
# Print the results
print(result.res2d)

# Plot the results
gp.plot.gseaplot(rank_metric=result.ranking, term="GLYCOLYSIS")
